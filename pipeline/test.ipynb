# %%
from corpus_pipeline import CorpusPipeline

cp = CorpusPipeline('config.json')

cp.build_corpus('../texts/alpha/', 'corpus_data')
# Out:
# Parser debugging for NenaLexerParser.<locals>.NenaParser written to parser.out
# Beginning parsing of NENA formatted texts...
# 	parsing ../texts/alpha/A Close Shave.nena...
# 	parsing ../texts/alpha/A Cure for a Husband’s Madness.nena...
# 	parsing ../texts/alpha/A Donkey Knows Best.nena...
# 	parsing ../texts/alpha/A Dragon in the Well.nena...
# 	parsing ../texts/alpha/A Dutiful Son.nena...
# 	parsing ../texts/alpha/A Frog Wants a Husband.nena...
# 	parsing ../texts/alpha/A Hundred Gold Coins.nena...
# 	parsing ../texts/alpha/A Lost Donkey.nena...
# 	parsing ../texts/alpha/A Lost Ring.nena...
# 	parsing ../texts/alpha/A Man Called Čuxo.nena...
# 	parsing ../texts/alpha/A Painting of the King of Iran.nena...
# 	parsing ../texts/alpha/A Pound of Flesh.nena...
# 	parsing ../texts/alpha/A Sweater to Pay Off a Debt.nena...
# 	parsing ../texts/alpha/A Tale of Two Kings.nena...
# 	parsing ../texts/alpha/A Tale of a Prince and a Princess.nena...
# 	parsing ../texts/alpha/A Thousand Dinars.nena...
# 	parsing ../texts/alpha/A Visit From Harun Ar-Rashid.nena...
# 	parsing ../texts/alpha/Agriculture and Village Life.nena...
# 	parsing ../texts/alpha/Am I Dead?.nena...
# 	parsing ../texts/alpha/An Orphan Duckling.nena...
# 	parsing ../texts/alpha/Axiqar.nena...
# 	parsing ../texts/alpha/Baby Leliθa.nena...
# 	parsing ../texts/alpha/Bread_and_cheese.nena...
# 	parsing ../texts/alpha/Dəmdəma.nena...
# 	parsing ../texts/alpha/Events in 1946 on the Urmi Plain.nena...
# 	parsing ../texts/alpha/Games.nena...
# 	parsing ../texts/alpha/Gozali and Nozali.nena...
# 	parsing ../texts/alpha/Hunting.nena...
# 	parsing ../texts/alpha/I Am Worth the Same as a Blind Wolf.nena...
# 	parsing ../texts/alpha/I Have Died.nena...
# 	parsing ../texts/alpha/Ice for Dinner.nena...
# 	parsing ../texts/alpha/Is There a Man With No Worries?.nena...
# 	parsing ../texts/alpha/Kindness to a Donkey.nena...
# 	parsing ../texts/alpha/Lost Money.nena...
# 	parsing ../texts/alpha/Man Is Treacherous.nena...
# 	parsing ../texts/alpha/Measure for Measure.nena...
# 	parsing ../texts/alpha/Mistaken Identity.nena...
# 	parsing ../texts/alpha/Much Ado About Nothing.nena...
# 	parsing ../texts/alpha/Nanno and Jəndo.nena...
# 	parsing ../texts/alpha/Nipuxta.nena...
# 	parsing ../texts/alpha/No Bread Today.nena...
# 	parsing ../texts/alpha/Problems Lighting a Fire.nena...
# 	parsing ../texts/alpha/Qaṭina Rescues His Nephew From Leliθa.nena...
# 	parsing ../texts/alpha/Sour Grapes.nena...
# 	parsing ../texts/alpha/St. Zayya’s Cake Dough.nena...
# 	parsing ../texts/alpha/Star-Crossed Lovers.nena...
# 	parsing ../texts/alpha/Stomach Trouble.nena...
# 	parsing ../texts/alpha/Tales From the 1001 Nights.nena...
# 	parsing ../texts/alpha/The Adventures of Ashur.nena...
# 	parsing ../texts/alpha/The Adventures of Two Brothers.nena...
# 	parsing ../texts/alpha/The Adventures of a Princess.nena...
# 	parsing ../texts/alpha/The Angel of Death.nena...
# 	parsing ../texts/alpha/The Assyrians of Armenia.nena...
# 	parsing ../texts/alpha/The Assyrians of Urmi.nena...
# 	parsing ../texts/alpha/The Bald Child and the Monsters.nena...
# 	parsing ../texts/alpha/The Bald Man and the King.nena...
# 	parsing ../texts/alpha/The Battle With Yuwanəs the Armenian.nena...
# 	parsing ../texts/alpha/The Bear and the Fox.nena...
# 	parsing ../texts/alpha/The Bird and the Fox.nena...
# 	parsing ../texts/alpha/The Brother of Giants.nena...
# 	parsing ../texts/alpha/The Cat and the Mice.nena...
# 	parsing ../texts/alpha/The Cat’s Dinner.nena...
# 	parsing ../texts/alpha/The Cooking Pot.nena...
# 	parsing ../texts/alpha/The Cow and the Poor Girl.nena...
# 	parsing ../texts/alpha/The Crafty Hireling.nena...
# 	parsing ../texts/alpha/The Crow and the Cheese.nena...
# 	parsing ../texts/alpha/The Daughter of the King.nena...
# 	parsing ../texts/alpha/The Dead Rise and Return.nena...
# 	parsing ../texts/alpha/The Fisherman and the Princess.nena...
# 	parsing ../texts/alpha/The Fox and the Lion.nena...
# 	parsing ../texts/alpha/The Fox and the Miller.nena...
# 	parsing ../texts/alpha/The Fox and the Stork.nena...
# 	parsing ../texts/alpha/The Giant One-Eyed Demon.nena...
# 	parsing ../texts/alpha/The Giant’s Cave.nena...
# 	parsing ../texts/alpha/The Girl and the Seven Brothers.nena...
# 	parsing ../texts/alpha/The King With Forty Sons.nena...
# 	parsing ../texts/alpha/The Leliθa From č̭āl.nena...
# 	parsing ../texts/alpha/The Lion King.nena...
# 	parsing ../texts/alpha/The Lion With a Swollen Leg.nena...
# 	parsing ../texts/alpha/The Little Prince and the Snake.nena...
# 	parsing ../texts/alpha/The Loan of a Cooking Pot.nena...
# 	parsing ../texts/alpha/The Man Who Cried Wolf.nena...
# 	parsing ../texts/alpha/The Man Who Wanted to Complain to God.nena...
# 	parsing ../texts/alpha/The Man Who Wanted to Work.nena...
# 	parsing ../texts/alpha/The Monk Who Wanted to Know When He Would Die.nena...
# 	parsing ../texts/alpha/The Monk and the Angel.nena...
# 	parsing ../texts/alpha/The Old Man and the Fish.nena...
# 	parsing ../texts/alpha/The Priest and the Mullah.nena...
# 	parsing ../texts/alpha/The Purchase of a Donkey.nena...
# 	parsing ../texts/alpha/The Sale of an Ox.nena...
# 	parsing ../texts/alpha/The Scorpion and the Snake.nena...
# 	parsing ../texts/alpha/The Selfish Neighbour.nena...
# 	parsing ../texts/alpha/The Sisisambər Plant.nena...
# 	parsing ../texts/alpha/The Snake’s Dilemma.nena...
# 	parsing ../texts/alpha/The Story With No End.nena...
# 	parsing ../texts/alpha/The Stupid Carpenter.nena...
# 	parsing ../texts/alpha/The Tale of Farxo and Səttiya.nena...
# 	parsing ../texts/alpha/The Tale of Mămo and Zine.nena...
# 	parsing ../texts/alpha/The Tale of Mərza Pămət.nena...
# 	parsing ../texts/alpha/The Tale of Nasimo.nena...
# 	parsing ../texts/alpha/The Tale of Parizada, Warda and Nargis.nena...
# 	parsing ../texts/alpha/The Tale of Rustam (1).nena...
# 	parsing ../texts/alpha/The Tale of Rustam (2).nena...
# 	parsing ../texts/alpha/The Wife Who Learns How to Work (2).nena...
# 	parsing ../texts/alpha/The Wife Who Learns How to Work.nena...
# 	parsing ../texts/alpha/The Wife’s Condition.nena...
# 	parsing ../texts/alpha/The Wise Brother.nena...
# 	parsing ../texts/alpha/The Wise Daughter of the King.nena...
# 	parsing ../texts/alpha/The Wise Snake.nena...
# 	parsing ../texts/alpha/The Wise Young Daughter.nena...
# 	parsing ../texts/alpha/The Wise Young Man.nena...
# 	parsing ../texts/alpha/Trickster.nena...
# 	parsing ../texts/alpha/Two Birds Fall in Love.nena...
# 	parsing ../texts/alpha/Two Wicked Daughters-In-Law.nena...
# 	parsing ../texts/alpha/Village Life (2).nena...
# 	parsing ../texts/alpha/Village Life (3).nena...
# 	parsing ../texts/alpha/Village Life (4).nena...
# 	parsing ../texts/alpha/Village Life (5).nena...
# 	parsing ../texts/alpha/Village Life (6).nena...
# 	parsing ../texts/alpha/Village Life.nena...
# 	parsing ../texts/alpha/Vineyards.nena...
# 	parsing ../texts/alpha/Weddings and Festivals.nena...
# 	parsing ../texts/alpha/Weddings.nena...
# 	parsing ../texts/alpha/When Shall I Die?.nena...
# 	parsing ../texts/alpha/Women Are Stronger Than Men.nena...
# 	parsing ../texts/alpha/Women Do Things Best.nena...
# 	parsing ../texts/alpha/Šošət Xere.nena...
# DONE parsing all .nena texts!
#
# Indexing new corpus data...
# This is Text-Fabric 8.5.12
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 0 features found and 0 ignored
#   0.00s Warp feature "otype" not found in
# corpus_data/tf/
#   0.00s Warp feature "oslots" not found in
# corpus_data/tf/
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    dialect, text, line
#    |   SECTION   FEATURES: dialect, title, line_number
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   text-orig-full       text, text_end
#    |      |   text-orig-lite       lite, lite_end
#    |      |   text-trans-full      full, full_end
#    |      |   text-trans-fuzzy     fuzzy, fuzzy_end
#    |      |   text-trans-lite      lite, lite_end
#    |     0.02s OK
#    |     0.00s Following director...
#   0.00s indexing all dialects / texts...
#    |     0.00s indexing alquosh, Bread and cheese...
#    |     0.09s indexing barwar, A Hundred Gold Coins...
#    |     0.14s indexing barwar, A Man Called Čuxo...
#    |     0.26s indexing barwar, A Tale of Two Kings...
#    |     0.33s indexing barwar, A Tale of a Prince and a Princess...
#    |     0.62s indexing barwar, Baby Leliθa...
#    |     0.75s indexing barwar, Dəmdəma...
#    |     0.84s indexing barwar, Gozali and Nozali...
#    |     1.42s indexing barwar, I Am Worth the Same as a Blind Wolf...
#    |     1.51s indexing barwar, Man Is Treacherous...
#    |     1.54s indexing barwar, Measure for Measure...
#    |     1.56s indexing barwar, Nanno and Jəndo...
#    |     1.68s indexing barwar, Qaṭina Rescues His Nephew From Leliθa...
#    |      |    -0.00s 	force-closing subsentence in §0.80
#    |      |     0.00s 	force-closing sentence in §0.80
#    |      |     0.01s 	force-closing subsentence in §1.57
#    |      |     0.02s 	force-closing sentence in §1.57
#    |      |     0.02s 	force-closing subsentence in §2.17
#    |      |     0.02s 	force-closing sentence in §2.17
#    |      |     0.04s 	force-closing sentence in §3.68
#    |      |     0.05s 	force-closing subsentence in §4.38
#    |      |     0.05s 	force-closing sentence in §4.38
#    |      |     0.05s 	force-closing subsentence in §5.20
#    |      |     0.06s 	force-closing sentence in §5.20
#    |      |     0.06s 	force-closing subsentence in §6.17
#    |      |     0.06s 	force-closing sentence in §6.17
#    |      |     0.07s 	force-closing subsentence in §7.13
#    |      |     0.07s 	force-closing sentence in §7.13
#    |      |     0.08s 	force-closing subsentence in §8.19
#    |      |     0.08s 	force-closing sentence in §8.19
#    |     1.81s indexing barwar, Sour Grapes...
#    |     1.83s indexing barwar, Tales From the 1001 Nights...
#    |     2.35s indexing barwar, The Battle With Yuwanəs the Armenian...
#    |      |     0.67s 	force-closing subsentence in §1.17
#    |      |     0.67s 	force-closing sentence in §1.17
#    |      |     0.75s 	force-closing subsentence in §2.513
#    |      |     0.75s 	force-closing sentence in §2.513
#    |      |     0.75s 	force-closing subsentence in §3.37
#    |      |     0.75s 	force-closing sentence in §3.37
#    |      |     0.77s 	force-closing sentence in §4.127
#    |      |     0.77s 	force-closing subsentence in §5.10
#    |      |     0.78s 	force-closing sentence in §5.10
#    |     2.47s indexing barwar, The Bear and the Fox...
#    |     2.54s indexing barwar, The Brother of Giants...
#    |     2.62s indexing barwar, The Cat and the Mice...
#    |     2.63s indexing barwar, The Cooking Pot...
#    |     2.67s indexing barwar, The Crafty Hireling...
#    |     2.87s indexing barwar, The Crow and the Cheese...
#    |      |     1.18s 	force-closing subsentence in §0.76
#    |      |     1.18s 	force-closing sentence in §0.76
#    |     2.88s indexing barwar, The Daughter of the King...
#    |     3.06s indexing barwar, The Fox and the Lion...
#    |     3.07s indexing barwar, The Fox and the Miller...
#    |     3.50s indexing barwar, The Fox and the Stork...
#    |     3.52s indexing barwar, The Giant’s Cave...
#    |     3.59s indexing barwar, The Girl and the Seven Brothers...
#    |      |     1.91s 	force-closing sentence in §0.61
#    |      |     1.91s 	force-closing subsentence in §1.8
#    |      |     1.91s 	force-closing sentence in §1.8
#    |     3.72s indexing barwar, The King With Forty Sons...
#    |     4.21s indexing barwar, The Leliθa From č̭āl...
#    |     4.26s indexing barwar, The Lion King...
#    |     4.27s indexing barwar, The Lion With a Swollen Leg...
#    |     4.35s indexing barwar, The Man Who Cried Wolf...
#    |     4.38s indexing barwar, The Man Who Wanted to Work...
#    |     4.60s indexing barwar, The Monk Who Wanted to Know When He Would Die...
#    |     4.66s indexing barwar, The Monk and the Angel...
#    |     4.77s indexing barwar, The Priest and the Mullah...
#    |     4.82s indexing barwar, The Sale of an Ox...
#    |     5.02s indexing barwar, The Scorpion and the Snake...
#    |     5.06s indexing barwar, The Selfish Neighbour...
#    |     5.08s indexing barwar, The Sisisambər Plant...
#    |      |     3.41s 	force-closing subsentence in §2.109
#    |      |     3.42s 	force-closing sentence in §2.109
#    |      |     3.42s 	force-closing subsentence in §3.17
#    |      |     3.42s 	force-closing sentence in §3.17
#    |      |     3.45s 	force-closing subsentence in §4.162
#    |      |     3.45s 	force-closing sentence in §4.162
#    |      |     3.45s 	force-closing subsentence in §5.13
#    |      |     3.45s 	force-closing sentence in §5.13
#    |     5.16s indexing barwar, The Story With No End...
#    |     5.18s indexing barwar, The Tale of Farxo and Səttiya...
#    |     5.55s indexing barwar, The Tale of Mămo and Zine...
#    |     5.96s indexing barwar, The Tale of Mərza Pămət...
#    |     6.13s indexing barwar, The Tale of Nasimo...
#    |      |     4.45s 	force-closing sentence in §0.87
#    |      |     4.45s 	force-closing subsentence in §1.38
#    |      |     4.45s 	force-closing sentence in §1.38
#    |      |     4.46s 	force-closing sentence in §2.21
#    |     6.20s indexing barwar, The Tale of Parizada, Warda and Nargis...
#    |     6.48s indexing barwar, The Tale of Rustam (1)...
#    |     6.61s indexing barwar, The Tale of Rustam (2)...
#    |     6.85s indexing barwar, The Wise Daughter of the King...
#    |     6.90s indexing barwar, The Wise Snake...
#    |      |     5.21s 	force-closing sentence in §0.15
#    |     7.02s indexing barwar, The Wise Young Man...
#    |     7.18s indexing barwar, Šošət Xere...
#    |      |     5.51s 	force-closing subsentence in §0.204
#    |      |     5.51s 	force-closing sentence in §0.204
#    |      |     5.52s 	force-closing sentence in §2.42
#    |     7.25s indexing urmi_c, A Close Shave...
#    |     7.26s indexing urmi_c, A Cure for a Husband’s Madness...
#    |     7.44s indexing urmi_c, A Donkey Knows Best...
#    |     7.46s indexing urmi_c, A Dragon in the Well...
#    |     7.54s indexing urmi_c, A Dutiful Son...
#    |     7.68s indexing urmi_c, A Frog Wants a Husband...
#    |     7.75s indexing urmi_c, A Lost Donkey...
#    |     7.76s indexing urmi_c, A Lost Ring...
#    |     7.77s indexing urmi_c, A Painting of the King of Iran...
#    |     7.89s indexing urmi_c, A Pound of Flesh...
#    |     8.00s indexing urmi_c, A Sweater to Pay Off a Debt...
#    |     8.02s indexing urmi_c, A Thousand Dinars...
#    |      |     6.36s 	foreign letter ŏ̀ encountered...
#    |     8.09s indexing urmi_c, A Visit From Harun Ar-Rashid...
#    |     8.17s indexing urmi_c, Agriculture and Village Life...
#    |     8.52s indexing urmi_c, Am I Dead?...
#    |     8.53s indexing urmi_c, An Orphan Duckling...
#    |     8.55s indexing urmi_c, Axiqar...
#    |     8.93s indexing urmi_c, Events in 1946 on the Urmi Plain...
#    |     9.01s indexing urmi_c, Games...
#    |     9.13s indexing urmi_c, Hunting...
#    |     9.26s indexing urmi_c, I Have Died...
#    |     9.28s indexing urmi_c, Ice for Dinner...
#    |     9.29s indexing urmi_c, Is There a Man With No Worries?...
#    |     9.41s indexing urmi_c, Kindness to a Donkey...
#    |     9.42s indexing urmi_c, Lost Money...
#    |     9.43s indexing urmi_c, Mistaken Identity...
#    |     9.45s indexing urmi_c, Much Ado About Nothing...
#    |      |     7.78s 	foreign letter ä encountered...
#    |      |     7.78s 	foreign letter ä̀ encountered...
#    |      |     7.78s 	foreign letter ä encountered...
#    |      |     7.78s 	foreign letter ä̀ encountered...
#    |     9.52s indexing urmi_c, Nipuxta...
#    |     9.58s indexing urmi_c, No Bread Today...
#    |     9.61s indexing urmi_c, Problems Lighting a Fire...
#    |     9.63s indexing urmi_c, St. Zayya’s Cake Dough...
#    |     9.71s indexing urmi_c, Star-Crossed Lovers...
#    |     9.75s indexing urmi_c, Stomach Trouble...
#    |     9.75s indexing urmi_c, The Adventures of Ashur...
#    |      |     8.11s 	foreign letter ǜ encountered...
#    |       10s indexing urmi_c, The Adventures of Two Brothers...
#    |       10s indexing urmi_c, The Adventures of a Princess...
#    |      |     8.93s 	foreign letter ǘ encountered...
#    |      |     8.94s 	foreign letter ǘ encountered...
#    |      |     8.94s 	foreign letter ü encountered...
#    |      |     8.94s 	foreign letter ü encountered...
#    |      |     8.96s 	foreign letter ǘ encountered...
#    |      |     8.96s 	foreign letter ǘ encountered...
#    |      |     8.96s 	foreign letter ü encountered...
#    |       11s indexing urmi_c, The Angel of Death...
#    |       11s indexing urmi_c, The Assyrians of Armenia...
#    |       11s indexing urmi_c, The Assyrians of Urmi...
#    |       12s indexing urmi_c, The Bald Child and the Monsters...
#    |       12s indexing urmi_c, The Bald Man and the King...
#    |       12s indexing urmi_c, The Bird and the Fox...
#    |       12s indexing urmi_c, The Cat’s Dinner...
#    |       12s indexing urmi_c, The Cow and the Poor Girl...
#    |       13s indexing urmi_c, The Dead Rise and Return...
#    |       13s indexing urmi_c, The Fisherman and the Princess...
#    |       13s indexing urmi_c, The Giant One-Eyed Demon...
#    |       13s indexing urmi_c, The Little Prince and the Snake...
#    |       13s indexing urmi_c, The Loan of a Cooking Pot...
#    |       13s indexing urmi_c, The Man Who Wanted to Complain to God...
#    |       13s indexing urmi_c, The Old Man and the Fish...
#    |       13s indexing urmi_c, The Purchase of a Donkey...
#    |       13s indexing urmi_c, The Snake’s Dilemma...
#    |       13s indexing urmi_c, The Stupid Carpenter...
#    |      |       12s 	foreign letter ã̀ encountered...
#    |       13s indexing urmi_c, The Wife Who Learns How to Work (2)...
#    |       13s indexing urmi_c, The Wife Who Learns How to Work...
#    |       13s indexing urmi_c, The Wife’s Condition...
#    |       13s indexing urmi_c, The Wise Brother...
#    |       14s indexing urmi_c, The Wise Young Daughter...
#    |       14s indexing urmi_c, Trickster...
#    |       14s indexing urmi_c, Two Birds Fall in Love...
#    |       14s indexing urmi_c, Two Wicked Daughters-In-Law...
#    |      |       12s 	foreign letter ü encountered...
#    |      |       12s 	foreign letter ü encountered...
#    |       14s indexing urmi_c, Village Life (2)...
#    |       14s indexing urmi_c, Village Life (3)...
#    |      |       12s 	foreign letter ý encountered...
#    |       14s indexing urmi_c, Village Life (4)...
#    |       15s indexing urmi_c, Village Life (5)...
#    |       15s indexing urmi_c, Village Life (6)...
#    |       15s indexing urmi_c, Village Life...
#    |       15s indexing urmi_c, Vineyards...
#    |       15s indexing urmi_c, Weddings and Festivals...
#    |       15s indexing urmi_c, Weddings...
#    |       15s indexing urmi_c, When Shall I Die?...
#    |      |       14s 	foreign letter ŏ́ encountered...
#    |       15s indexing urmi_c, Women Are Stronger Than Men...
#    |       16s indexing urmi_c, Women Do Things Best...
#    |       16s "edge" actions: 0
#    |       16s "feature" actions: 4304221
#    |       16s "node" actions: 295347
#    |       16s "resume" actions: 0
#    |       16s "slot" actions: 541384
#    |       16s "terminate" actions: 836857
#    |          3 x "dialect" node
#    |      36594 x "inton" node
#    |     541384 x "letter" node  = slot type
#    |       2587 x "line" node
#    |        351 x "paragraph" node
#    |      16369 x "sentence" node
#    |      94101 x "stress" node
#    |      24617 x "subsentence" node
#    |        127 x "text" node
#    |     120598 x "word" node
#    |     836731 nodes of all types
#    |       16s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking features ...
#    |     0.00s OK
#    |     0.00s reordering nodes ...
#    |     0.16s Sorting 3 nodes of type "dialect"
#    |     0.20s Sorting 36594 nodes of type "inton"
#    |     0.32s Sorting 2587 nodes of type "line"
#    |     0.36s Sorting 351 nodes of type "paragraph"
#    |     0.41s Sorting 16369 nodes of type "sentence"
#    |     0.48s Sorting 94101 nodes of type "stress"
#    |     0.67s Sorting 24617 nodes of type "subsentence"
#    |     0.80s Sorting 127 nodes of type "text"
#    |     0.84s Sorting 120598 nodes of type "word"
#    |     1.06s Max node = 836731
#    |     1.06s OK
#    |     0.00s reassigning feature values ...
#    |      |       16s node feature "dialect" with 130 nodes
#    |      |       16s node feature "full" with 661982 nodes
#    |      |       16s node feature "full_end" with 120586 nodes
#    |      |       16s node feature "fuzzy" with 661982 nodes
#    |      |       16s node feature "fuzzy_end" with 120598 nodes
#    |      |       16s node feature "lang" with 120598 nodes
#    |      |       16s node feature "line_number" with 2587 nodes
#    |      |       16s node feature "lite" with 661982 nodes
#    |      |       16s node feature "lite_end" with 120586 nodes
#    |      |       16s node feature "phonation" with 307888 nodes
#    |      |       16s node feature "phonetic_class" with 541366 nodes
#    |      |       16s node feature "phonetic_manner" with 312113 nodes
#    |      |       17s node feature "phonetic_place" with 312113 nodes
#    |      |       17s node feature "place" with 127 nodes
#    |      |       17s node feature "speaker" with 120598 nodes
#    |      |       17s node feature "speakers" with 126 nodes
#    |      |       17s node feature "text" with 661982 nodes
#    |      |       17s node feature "text_end" with 120598 nodes
#    |      |       17s node feature "text_id" with 126 nodes
#    |      |       17s node feature "text_nostress" with 661982 nodes
#    |      |       17s node feature "text_nostress_end" with 120586 nodes
#    |      |       17s node feature "timestamp" with 447 nodes
#    |      |       17s node feature "title" with 127 nodes
#    |     1.87s OK
#   0.00s Exporting 24 node and 1 edge and 1 config features to corpus_data/tf:
#   0.00s VALIDATING oslots feature
#   0.10s VALIDATING oslots feature
#   0.10s maxSlot=     541384
#   0.10s maxNode=     836731
#   0.15s OK: oslots is valid
#    |     0.00s T dialect              to corpus_data/tf
#    |     0.68s T full                 to corpus_data/tf
#    |     0.13s T full_end             to corpus_data/tf
#    |     0.64s T fuzzy                to corpus_data/tf
#    |     0.13s T fuzzy_end            to corpus_data/tf
#    |     0.12s T lang                 to corpus_data/tf
#    |     0.00s T line_number          to corpus_data/tf
#    |     0.73s T lite                 to corpus_data/tf
#    |     0.14s T lite_end             to corpus_data/tf
#    |     0.21s T otype                to corpus_data/tf
#    |     0.37s T phonation            to corpus_data/tf
#    |     0.58s T phonetic_class       to corpus_data/tf
#    |     0.35s T phonetic_manner      to corpus_data/tf
#    |     0.35s T phonetic_place       to corpus_data/tf
#    |     0.00s T place                to corpus_data/tf
#    |     0.16s T speaker              to corpus_data/tf
#    |     0.00s T speakers             to corpus_data/tf
#    |     0.74s T text                 to corpus_data/tf
#    |     0.14s T text_end             to corpus_data/tf
#    |     0.00s T text_id              to corpus_data/tf
#    |     0.69s T text_nostress        to corpus_data/tf
#    |     0.16s T text_nostress_end    to corpus_data/tf
#    |     0.00s T timestamp            to corpus_data/tf
#    |     0.00s T title                to corpus_data/tf
#    |     1.17s T oslots               to corpus_data/tf
#    |     0.00s M otext                to corpus_data/tf
#   7.66s Exported 24 node features and 1 edge features and 1 config features to corpus_data/tf
# 	SUCCESS! TF corpus built.
#
# Loading TF data and building documentation...
# This is Text-Fabric 8.5.12
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 26 features found and 0 ignored
#   0.00s loading features ...
#    |     0.31s T otype                from corpus_data/tf
#    |     4.20s T oslots               from corpus_data/tf
#    |     0.00s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.00s T dialect              from corpus_data/tf
#    |     0.24s T fuzzy_end            from corpus_data/tf
#    |     0.22s T lite_end             from corpus_data/tf
#    |     1.29s T text                 from corpus_data/tf
#    |     0.00s T line_number          from corpus_data/tf
#    |     0.21s T full_end             from corpus_data/tf
#    |     0.00s T title                from corpus_data/tf
#    |     1.24s T lite                 from corpus_data/tf
#    |     1.25s T full                 from corpus_data/tf
#    |     0.22s T text_end             from corpus_data/tf
#    |     1.19s T fuzzy                from corpus_data/tf
#    |      |     0.19s C __levels__           from otype, oslots, otext
#    |      |       10s C __order__            from otype, oslots, __levels__
#    |      |     0.38s C __rank__             from otype, __order__
#    |      |     8.33s C __levUp__            from otype, oslots, __rank__
#    |      |     2.44s C __levDown__          from otype, __levUp__, __rank__
#    |      |     2.84s C __boundary__         from otype, oslots, __rank__
#    |      |     0.01s C __sections__         from otype, oslots, otext, __levUp__, __levels__, dialect, title, line_number
#     35s All features loaded/computed - for details use loadLog()
#   0.00s loading features ...
#    |     0.24s T lang                 from corpus_data/tf
#    |     0.81s T phonation            from corpus_data/tf
#    |     1.08s T phonetic_class       from corpus_data/tf
#    |     0.78s T phonetic_manner      from corpus_data/tf
#    |     0.80s T phonetic_place       from corpus_data/tf
#    |     0.00s T place                from corpus_data/tf
#    |     0.24s T speaker              from corpus_data/tf
#    |     0.00s T speakers             from corpus_data/tf
#    |     0.00s T text_id              from corpus_data/tf
#    |     1.25s T text_nostress        from corpus_data/tf
#    |     0.22s T text_nostress_end    from corpus_data/tf
#    |     0.00s T timestamp            from corpus_data/tf
#   5.44s All additional features loaded - for details use loadLog()
# 	done!
#
# Building search tool...
# This is Text-Fabric 8.5.12
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 26 features found and 0 ignored
#   0.00s loading features ...
#    |     0.00s Dataset without structure sections in otext:no structure functions in the T-API
#   1.77s All features loaded/computed - for details use loadLog()
#   0.00s loading features ...
#   0.33s All additional features loaded - for details use loadLog()
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 8.5.12</a>, <a target="_blank" href="https://github.com/annotation/app-search_configs" title="search_configs TF-app">app-search_configs v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br><b>Data:</b> <a target="_blank" href="https://github.com/CambridgeSemiticsLab/nena_tf/blob/master/docs/features.md.md" title="provenance of Northeastern Neo-Aramaic Text Corpus">NENA_TF</a>, <a target="_blank" href="https://github.com/CambridgeSemiticsLab/nena_tf/blob/master/docs/transcription.md" title="NENA transcription script">Character table</a>, <a target="_blank" href="https://github.com/CambridgeSemiticsLab/nena_tf/blob/master/docs/features.md#" title="NENA_TF feature documentation">Feature docs</a><br><b>Features:</b><br><details><summary><b>corpus_data/tf/</b></summary><span title="corpus_data/tf//dialect.tf">dialect</span><br><span title="corpus_data/tf//full.tf">full</span><br><span title="corpus_data/tf//full_end.tf">full_end</span><br><span title="corpus_data/tf//fuzzy.tf">fuzzy</span><br><span title="corpus_data/tf//fuzzy_end.tf">fuzzy_end</span><br><span title="corpus_data/tf//lang.tf">lang</span><br><span title="corpus_data/tf//line_number.tf">line_number</span><br><span title="corpus_data/tf//lite.tf">lite</span><br><span title="corpus_data/tf//lite_end.tf">lite_end</span><br><span title="corpus_data/tf//otype.tf">otype</span><br><span title="corpus_data/tf//phonation.tf">phonation</span><br><span title="corpus_data/tf//phonetic_class.tf">phonetic_class</span><br><span title="corpus_data/tf//phonetic_manner.tf">phonetic_manner</span><br><span title="corpus_data/tf//phonetic_place.tf">phonetic_place</span><br><span title="corpus_data/tf//place.tf">place</span><br><span title="corpus_data/tf//speaker.tf">speaker</span><br><span title="corpus_data/tf//speakers.tf">speakers</span><br><span title="corpus_data/tf//text.tf">text</span><br><span title="corpus_data/tf//text_end.tf">text_end</span><br><span title="corpus_data/tf//text_id.tf">text_id</span><br><span title="corpus_data/tf//text_nostress.tf">text_nostress</span><br><span title="corpus_data/tf//text_nostress_end.tf">text_nostress_end</span><br><span title="corpus_data/tf//timestamp.tf">timestamp</span><br><span title="corpus_data/tf//title.tf">title</span><br><b><i><span title="corpus_data/tf//oslots.tf">oslots</span></i></b><br></details>
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# o-o-o-o-o-o-o phono o-o-o-o-o-o-o-o
#
#
# Node type declared as result focus:
#
# 	sentence
#
# Layers declared as visible in the result ('visible'):
#
# 	word/text, word/fuzzy
#
#   0.46s Config written to file corpus_data/search_tool/phono/corpus/config.js
#   0.46s Make links ...
#   0.46s links for types text, line
# text                :    127 links
# line                :   2587 links
#   0.58s done
#   0.58s Recording ...
#   0.00s preparing ...
#   0.00s start recording
# 127 Women Do Things Best
#   8.65s done
#   8.65s Dumping ...
#   8.65s wrap recorders for delivery
#   8.65s 	word
#   8.65s 		text
#   8.85s 		full
#   9.04s 		fuzzy
#   9.21s 		lite
#   9.38s 		cls
#   9.55s 		lang
#   9.64s 		speaker
#   9.74s 	line
#   9.74s 		number
#   9.74s 	text
#   9.75s 		title
#   9.75s 		tid
#   9.75s 		dialect
#   9.75s 		place
#   9.75s wrap accumulators for delivery
#   9.75s 	word
#   9.76s 		voice
#   9.77s 		place
#   9.79s 		manner
#   9.81s 	line
#   9.81s 	text
#   0.00s Dumping data to compact json files
#   0.01s Data texts-word-text stored in corpus_data/search_tool/phono/corpus/texts-word-text.js
#   0.02s Data texts-word-full stored in corpus_data/search_tool/phono/corpus/texts-word-full.js
#   0.03s Data texts-word-fuzzy stored in corpus_data/search_tool/phono/corpus/texts-word-fuzzy.js
#   0.04s Data texts-word-lite stored in corpus_data/search_tool/phono/corpus/texts-word-lite.js
#   0.05s Data texts-word-cls stored in corpus_data/search_tool/phono/corpus/texts-word-cls.js
#   0.05s Data texts-word-voice stored in corpus_data/search_tool/phono/corpus/texts-word-voice.js
#   0.06s Data texts-word-place stored in corpus_data/search_tool/phono/corpus/texts-word-place.js
#   0.07s Data texts-word-manner stored in corpus_data/search_tool/phono/corpus/texts-word-manner.js
#   0.08s Data texts-word-lang stored in corpus_data/search_tool/phono/corpus/texts-word-lang.js
#   0.08s Data texts-word-speaker stored in corpus_data/search_tool/phono/corpus/texts-word-speaker.js
#   0.08s Data texts-line-number stored in corpus_data/search_tool/phono/corpus/texts-line-number.js
#   0.08s Data texts-text-title stored in corpus_data/search_tool/phono/corpus/texts-text-title.js
#   0.09s Data texts-text-tid stored in corpus_data/search_tool/phono/corpus/texts-text-tid.js
#   0.09s Data texts-text-dialect stored in corpus_data/search_tool/phono/corpus/texts-text-dialect.js
#   0.09s Data texts-text-place stored in corpus_data/search_tool/phono/corpus/texts-text-place.js
#   0.53s Data posinfo-word-text stored in corpus_data/search_tool/phono/corpus/posinfo-word-text.js
#   0.96s Data posinfo-word-full stored in corpus_data/search_tool/phono/corpus/posinfo-word-full.js
#   1.31s Data posinfo-word-fuzzy stored in corpus_data/search_tool/phono/corpus/posinfo-word-fuzzy.js
#   1.71s Data posinfo-word-lite stored in corpus_data/search_tool/phono/corpus/posinfo-word-lite.js
#   2.18s Data posinfo-word-cls stored in corpus_data/search_tool/phono/corpus/posinfo-word-cls.js
#   2.40s Data posinfo-word-lang stored in corpus_data/search_tool/phono/corpus/posinfo-word-lang.js
#   2.58s Data posinfo-word-speaker stored in corpus_data/search_tool/phono/corpus/posinfo-word-speaker.js
#   2.59s Data posinfo-line-number stored in corpus_data/search_tool/phono/corpus/posinfo-line-number.js
#   2.59s Data posinfo-text-title stored in corpus_data/search_tool/phono/corpus/posinfo-text-title.js
#   2.59s Data posinfo-text-tid stored in corpus_data/search_tool/phono/corpus/posinfo-text-tid.js
#   2.60s Data posinfo-text-dialect stored in corpus_data/search_tool/phono/corpus/posinfo-text-dialect.js
#   2.60s Data posinfo-text-place stored in corpus_data/search_tool/phono/corpus/posinfo-text-place.js
#   2.62s Data up stored in corpus_data/search_tool/phono/corpus/up.js
#   2.62s Data links stored in corpus_data/search_tool/phono/corpus/links.js
# Copied static files
# job, feature, test, defs, disk, log, config, corpus, state, gui, mem, search, app
# Combined js file written to corpus_data/search_tool/phono/all.js
# html file written to corpus_data/search_tool/index.html
# html file written to corpus_data/search_tool/phono/index.html
# html file (for use with file://) written to corpus_data/search_tool/phono/index-local.html
# adding all.js
# adding css/phono.css
# adding css/ls.css
# adding index-local.html
# adding corpus/texts-word-manner.js
# adding corpus/texts-word-full.js
# adding corpus/posinfo-word-fuzzy.js
# adding corpus/texts-word-cls.js
# adding corpus/up.js
# adding corpus/texts-word-lite.js
# adding corpus/texts-word-text.js
# adding corpus/posinfo-line-number.js
# adding corpus/links.js
# adding corpus/texts-word-fuzzy.js
# adding corpus/texts-word-place.js
# adding corpus/posinfo-word-text.js
# adding corpus/posinfo-word-lite.js
# adding corpus/texts-text-title.js
# adding corpus/posinfo-word-full.js
# adding corpus/posinfo-text-title.js
# adding corpus/texts-text-tid.js
# adding corpus/config.js
# adding corpus/posinfo-text-place.js
# adding corpus/posinfo-text-tid.js
# adding corpus/init.js
# adding corpus/texts-word-lang.js
# adding corpus/texts-line-number.js
# adding corpus/texts-word-voice.js
# adding corpus/posinfo-word-speaker.js
# adding corpus/texts-text-place.js
# adding corpus/texts-text-dialect.js
# adding corpus/posinfo-word-lang.js
# adding corpus/posinfo-word-cls.js
# adding corpus/texts-word-speaker.js
# adding corpus/posinfo-text-dialect.js
# adding png/tf.png
# adding png/maker.png
# adding png/github.png
# adding png/phono.png
# adding jslib/jquery.js
# Packaged client into corpus_data/search_tool/phono.zip
# Adjusting debug in corpus_data/search_tool/phono/js/defs.js
# Debug set to false
#
#
# o-o-o-o-o-o-o fuzzy o-o-o-o-o-o-o-o
#
#
# Node type declared as result focus:
#
# 	sentence
#
# Layers declared as visible in the result ('visible'):
#
# 	word/fuzzy, line/number, text/title, text/dialect
#
#   4.22s Config written to file corpus_data/search_tool/fuzzy/corpus/config.js
#   4.22s Make links ...
#   4.22s links for types text, line
# text                :    127 links
# line                :   2587 links
#   4.34s done
#   4.34s Recording ...
#   0.00s preparing ...
#   0.00s start recording
# 127 Women Do Things Best
#   1.44s done
#   1.44s Dumping ...
#   1.44s wrap recorders for delivery
#   1.45s 	word
#   1.45s 		fuzzy
#   1.61s 	line
#   1.61s 		number
#   1.61s 	text
#   1.61s 		title
#   1.61s 		dialect
#   1.62s wrap accumulators for delivery
#   1.62s 	word
#   1.62s 	line
#   1.62s 	text
#   0.00s Dumping data to compact json files
#   0.01s Data texts-word-fuzzy stored in corpus_data/search_tool/fuzzy/corpus/texts-word-fuzzy.js
#   0.01s Data texts-line-number stored in corpus_data/search_tool/fuzzy/corpus/texts-line-number.js
#   0.01s Data texts-text-title stored in corpus_data/search_tool/fuzzy/corpus/texts-text-title.js
#   0.01s Data texts-text-dialect stored in corpus_data/search_tool/fuzzy/corpus/texts-text-dialect.js
#   0.36s Data posinfo-word-fuzzy stored in corpus_data/search_tool/fuzzy/corpus/posinfo-word-fuzzy.js
#   0.37s Data posinfo-line-number stored in corpus_data/search_tool/fuzzy/corpus/posinfo-line-number.js
#   0.37s Data posinfo-text-title stored in corpus_data/search_tool/fuzzy/corpus/posinfo-text-title.js
#   0.37s Data posinfo-text-dialect stored in corpus_data/search_tool/fuzzy/corpus/posinfo-text-dialect.js
#   0.39s Data up stored in corpus_data/search_tool/fuzzy/corpus/up.js
#   0.40s Data links stored in corpus_data/search_tool/fuzzy/corpus/links.js
# Copied static files
# job, feature, test, defs, disk, log, config, corpus, state, gui, mem, search, app
# Combined js file written to corpus_data/search_tool/fuzzy/all.js
# html file written to corpus_data/search_tool/index.html
# html file written to corpus_data/search_tool/fuzzy/index.html
# html file (for use with file://) written to corpus_data/search_tool/fuzzy/index-local.html
# adding all.js
# adding css/fuzzy.css
# adding css/ls.css
# adding index-local.html
# adding corpus/posinfo-word-fuzzy.js
# adding corpus/up.js
# adding corpus/posinfo-line-number.js
# adding corpus/links.js
# adding corpus/texts-word-fuzzy.js
# adding corpus/texts-text-title.js
# adding corpus/posinfo-text-title.js
# adding corpus/config.js
# adding corpus/init.js
# adding corpus/texts-line-number.js
# adding corpus/texts-text-dialect.js
# adding corpus/posinfo-text-dialect.js
# adding png/tf.png
# adding png/fuzzy.png
# adding png/maker.png
# adding png/github.png
# adding jslib/jquery.js
# Packaged client into corpus_data/search_tool/fuzzy.zip
# Adjusting debug in corpus_data/search_tool/fuzzy/js/defs.js
# Debug set to false
# 	done!
