# %%
from corpus_pipeline import CorpusPipeline

# %%
cp = CorpusPipeline('config.json')

# %%
cp.build_corpus('../texts/alpha/', '')
# Out:
# Parser debugging for NenaLexerParser.<locals>.NenaParser written to parser.out
# Beginning parsing of NENA formatted texts...
# 	parsing ../texts/alpha/A Close Shave.nena...
# 	parsing ../texts/alpha/A Cure for a Husband’s Madness.nena...
# 	parsing ../texts/alpha/A Donkey Knows Best.nena...
# 	parsing ../texts/alpha/A Dragon in the Well.nena...
# 	parsing ../texts/alpha/A Dutiful Son.nena...
# 	parsing ../texts/alpha/A Frog Wants a Husband.nena...
# 	parsing ../texts/alpha/A Hundred Gold Coins.nena...
# 	parsing ../texts/alpha/A Lost Donkey.nena...
# 	parsing ../texts/alpha/A Lost Ring.nena...
# 	parsing ../texts/alpha/A Man Called Čuxo.nena...
# 	parsing ../texts/alpha/A Painting of the King of Iran.nena...
# 	parsing ../texts/alpha/A Pound of Flesh.nena...
# 	parsing ../texts/alpha/A Sweater to Pay Off a Debt.nena...
# 	parsing ../texts/alpha/A Tale of Two Kings.nena...
# 	parsing ../texts/alpha/A Tale of a Prince and a Princess.nena...
# 	parsing ../texts/alpha/A Thousand Dinars.nena...
# 	parsing ../texts/alpha/A Visit From Harun Ar-Rashid.nena...
# 	parsing ../texts/alpha/Agriculture and Village Life.nena...
# 	parsing ../texts/alpha/Am I Dead?.nena...
# 	parsing ../texts/alpha/An Orphan Duckling.nena...
# 	parsing ../texts/alpha/Axiqar.nena...
# 	parsing ../texts/alpha/Baby Leliθa.nena...
# 	parsing ../texts/alpha/Bread_and_cheese.nena...
# 	parsing ../texts/alpha/Dəmdəma.nena...
# 	parsing ../texts/alpha/Events in 1946 on the Urmi Plain.nena...
# 	parsing ../texts/alpha/Games.nena...
# 	parsing ../texts/alpha/Gozali and Nozali.nena...
# 	parsing ../texts/alpha/Hunting.nena...
# 	parsing ../texts/alpha/I Am Worth the Same as a Blind Wolf.nena...
# 	parsing ../texts/alpha/I Have Died.nena...
# 	parsing ../texts/alpha/Ice for Dinner.nena...
# 	parsing ../texts/alpha/Is There a Man With No Worries?.nena...
# 	parsing ../texts/alpha/Kindness to a Donkey.nena...
# 	parsing ../texts/alpha/Lost Money.nena...
# 	parsing ../texts/alpha/Man Is Treacherous.nena...
# 	parsing ../texts/alpha/Measure for Measure.nena...
# 	parsing ../texts/alpha/Mistaken Identity.nena...
# 	parsing ../texts/alpha/Much Ado About Nothing.nena...
# 	parsing ../texts/alpha/Nanno and Jəndo.nena...
# 	parsing ../texts/alpha/Nipuxta.nena...
# 	parsing ../texts/alpha/No Bread Today.nena...
# 	parsing ../texts/alpha/Problems Lighting a Fire.nena...
# 	parsing ../texts/alpha/Qaṭina Rescues His Nephew From Leliθa.nena...
# 	parsing ../texts/alpha/Sour Grapes.nena...
# 	parsing ../texts/alpha/St. Zayya’s Cake Dough.nena...
# 	parsing ../texts/alpha/Star-Crossed Lovers.nena...
# 	parsing ../texts/alpha/Stomach Trouble.nena...
# 	parsing ../texts/alpha/Tales From the 1001 Nights.nena...
# 	parsing ../texts/alpha/The Adventures of Ashur.nena...
# 	parsing ../texts/alpha/The Adventures of Two Brothers.nena...
# 	parsing ../texts/alpha/The Adventures of a Princess.nena...
# 	parsing ../texts/alpha/The Angel of Death.nena...
# 	parsing ../texts/alpha/The Assyrians of Armenia.nena...
# 	parsing ../texts/alpha/The Assyrians of Urmi.nena...
# 	parsing ../texts/alpha/The Bald Child and the Monsters.nena...
# 	parsing ../texts/alpha/The Bald Man and the King.nena...
# 	parsing ../texts/alpha/The Battle With Yuwanəs the Armenian.nena...
# 	parsing ../texts/alpha/The Bear and the Fox.nena...
# 	parsing ../texts/alpha/The Bird and the Fox.nena...
# 	parsing ../texts/alpha/The Brother of Giants.nena...
# 	parsing ../texts/alpha/The Cat and the Mice.nena...
# 	parsing ../texts/alpha/The Cat’s Dinner.nena...
# 	parsing ../texts/alpha/The Cooking Pot.nena...
# 	parsing ../texts/alpha/The Cow and the Poor Girl.nena...
# 	parsing ../texts/alpha/The Crafty Hireling.nena...
# 	parsing ../texts/alpha/The Crow and the Cheese.nena...
# 	parsing ../texts/alpha/The Daughter of the King.nena...
# 	parsing ../texts/alpha/The Dead Rise and Return.nena...
# 	parsing ../texts/alpha/The Fisherman and the Princess.nena...
# 	parsing ../texts/alpha/The Fox and the Lion.nena...
# 	parsing ../texts/alpha/The Fox and the Miller.nena...
# 	parsing ../texts/alpha/The Fox and the Stork.nena...
# 	parsing ../texts/alpha/The Giant One-Eyed Demon.nena...
# 	parsing ../texts/alpha/The Giant’s Cave.nena...
# 	parsing ../texts/alpha/The Girl and the Seven Brothers.nena...
# 	parsing ../texts/alpha/The King With Forty Sons.nena...
# 	parsing ../texts/alpha/The Leliθa From č̭āl.nena...
# 	parsing ../texts/alpha/The Lion King.nena...
# 	parsing ../texts/alpha/The Lion With a Swollen Leg.nena...
# 	parsing ../texts/alpha/The Little Prince and the Snake.nena...
# 	parsing ../texts/alpha/The Loan of a Cooking Pot.nena...
# 	parsing ../texts/alpha/The Man Who Cried Wolf.nena...
# 	parsing ../texts/alpha/The Man Who Wanted to Complain to God.nena...
# 	parsing ../texts/alpha/The Man Who Wanted to Work.nena...
# 	parsing ../texts/alpha/The Monk Who Wanted to Know When He Would Die.nena...
# 	parsing ../texts/alpha/The Monk and the Angel.nena...
# 	parsing ../texts/alpha/The Old Man and the Fish.nena...
# 	parsing ../texts/alpha/The Priest and the Mullah.nena...
# 	parsing ../texts/alpha/The Purchase of a Donkey.nena...
# 	parsing ../texts/alpha/The Sale of an Ox.nena...
# 	parsing ../texts/alpha/The Scorpion and the Snake.nena...
# 	parsing ../texts/alpha/The Selfish Neighbour.nena...
# 	parsing ../texts/alpha/The Sisisambər Plant.nena...
# 	parsing ../texts/alpha/The Snake’s Dilemma.nena...
# 	parsing ../texts/alpha/The Story With No End.nena...
# 	parsing ../texts/alpha/The Stupid Carpenter.nena...
# 	parsing ../texts/alpha/The Tale of Farxo and Səttiya.nena...
# 	parsing ../texts/alpha/The Tale of Mămo and Zine.nena...
# 	parsing ../texts/alpha/The Tale of Mərza Pămət.nena...
# 	parsing ../texts/alpha/The Tale of Nasimo.nena...
# 	parsing ../texts/alpha/The Tale of Parizada, Warda and Nargis.nena...
# 	parsing ../texts/alpha/The Tale of Rustam (1).nena...
# 	parsing ../texts/alpha/The Tale of Rustam (2).nena...
# 	parsing ../texts/alpha/The Wife Who Learns How to Work (2).nena...
# 	parsing ../texts/alpha/The Wife Who Learns How to Work.nena...
# 	parsing ../texts/alpha/The Wife’s Condition.nena...
# 	parsing ../texts/alpha/The Wise Brother.nena...
# 	parsing ../texts/alpha/The Wise Daughter of the King.nena...
# 	parsing ../texts/alpha/The Wise Snake.nena...
# 	parsing ../texts/alpha/The Wise Young Daughter.nena...
# 	parsing ../texts/alpha/The Wise Young Man.nena...
# 	parsing ../texts/alpha/Trickster.nena...
# 	parsing ../texts/alpha/Two Birds Fall in Love.nena...
# 	parsing ../texts/alpha/Two Wicked Daughters-In-Law.nena...
# 	parsing ../texts/alpha/Village Life (2).nena...
# 	parsing ../texts/alpha/Village Life (3).nena...
# 	parsing ../texts/alpha/Village Life (4).nena...
# 	parsing ../texts/alpha/Village Life (5).nena...
# 	parsing ../texts/alpha/Village Life (6).nena...
# 	parsing ../texts/alpha/Village Life.nena...
# 	parsing ../texts/alpha/Vineyards.nena...
# 	parsing ../texts/alpha/Weddings and Festivals.nena...
# 	parsing ../texts/alpha/Weddings.nena...
# 	parsing ../texts/alpha/When Shall I Die?.nena...
# 	parsing ../texts/alpha/Women Are Stronger Than Men.nena...
# 	parsing ../texts/alpha/Women Do Things Best.nena...
# 	parsing ../texts/alpha/Šošət Xere.nena...
# DONE parsing all .nena texts!
# This is Text-Fabric 8.4.14
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 26 features found and 0 ignored
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    dialect, text, line
#    |   SECTION   FEATURES: dialect, title, line_number
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   text-orig-full       text, text_end
#    |      |   text-orig-lite       lite, lite_end
#    |      |   text-trans-full      full, full_end
#    |      |   text-trans-fuzzy     fuzzy, fuzzy_end
#    |      |   text-trans-lite      lite, lite_end
#    |     0.01s OK
#    |     0.00s Following director...
#   0.00s indexing all dialects / texts...
#    |     0.00s indexing alquosh, Bread and cheese...
#    |     0.10s indexing barwar, A Hundred Gold Coins...
#    |     0.16s indexing barwar, A Man Called Čuxo...
#    |     0.29s indexing barwar, A Tale of Two Kings...
#    |     0.38s indexing barwar, A Tale of a Prince and a Princess...
#    |     0.66s indexing barwar, Baby Leliθa...
#    |     0.80s indexing barwar, Dəmdəma...
#    |     0.90s indexing barwar, Gozali and Nozali...
#    |     1.47s indexing barwar, I Am Worth the Same as a Blind Wolf...
#    |     1.54s indexing barwar, Man Is Treacherous...
#    |     1.58s indexing barwar, Measure for Measure...
#    |     1.60s indexing barwar, Nanno and Jəndo...
#    |     1.71s indexing barwar, Qaṭina Rescues His Nephew From Leliθa...
#    |      |    -0.00s 	force-closing sentence in §0.80
#    |      |     0.00s 	force-closing subsentence in §0.80
#    |      |     0.01s 	force-closing sentence in §1.57
#    |      |     0.02s 	force-closing subsentence in §1.57
#    |      |     0.02s 	force-closing sentence in §2.17
#    |      |     0.02s 	force-closing subsentence in §2.17
#    |      |     0.03s 	force-closing sentence in §3.68
#    |      |     0.04s 	force-closing sentence in §4.38
#    |      |     0.04s 	force-closing subsentence in §4.38
#    |      |     0.05s 	force-closing sentence in §5.20
#    |      |     0.05s 	force-closing subsentence in §5.20
#    |      |     0.05s 	force-closing sentence in §6.17
#    |      |     0.05s 	force-closing subsentence in §6.17
#    |      |     0.06s 	force-closing sentence in §7.13
#    |      |     0.06s 	force-closing subsentence in §7.13
#    |      |     0.07s 	force-closing sentence in §8.19
#    |      |     0.07s 	force-closing subsentence in §8.19
#    |     1.81s indexing barwar, Sour Grapes...
#    |     1.83s indexing barwar, Tales From the 1001 Nights...
#    |     2.30s indexing barwar, The Battle With Yuwanəs the Armenian...
#    |      |     0.60s 	force-closing sentence in §1.17
#    |      |     0.60s 	force-closing subsentence in §1.17
#    |      |     0.67s 	force-closing sentence in §2.513
#    |      |     0.67s 	force-closing subsentence in §2.513
#    |      |     0.68s 	force-closing sentence in §3.37
#    |      |     0.68s 	force-closing subsentence in §3.37
#    |      |     0.70s 	force-closing sentence in §4.127
#    |      |     0.71s 	force-closing sentence in §5.10
#    |      |     0.71s 	force-closing subsentence in §5.10
#    |     2.42s indexing barwar, The Bear and the Fox...
#    |     2.50s indexing barwar, The Brother of Giants...
#    |     2.58s indexing barwar, The Cat and the Mice...
#    |     2.59s indexing barwar, The Cooking Pot...
#    |     2.64s indexing barwar, The Crafty Hireling...
#    |     2.84s indexing barwar, The Crow and the Cheese...
#    |      |     1.13s 	force-closing sentence in §0.76
#    |      |     1.13s 	force-closing subsentence in §0.76
#    |     2.85s indexing barwar, The Daughter of the King...
#    |     3.04s indexing barwar, The Fox and the Lion...
#    |     3.06s indexing barwar, The Fox and the Miller...
#    |     3.19s indexing barwar, The Fox and the Stork...
#    |     3.20s indexing barwar, The Giant’s Cave...
#    |     3.24s indexing barwar, The Girl and the Seven Brothers...
#    |      |     1.53s 	force-closing sentence in §0.61
#    |      |     1.54s 	force-closing sentence in §1.8
#    |      |     1.54s 	force-closing subsentence in §1.8
#    |     3.38s indexing barwar, The King With Forty Sons...
#    |     3.75s indexing barwar, The Leliθa From č̭āl...
#    |     3.78s indexing barwar, The Lion King...
#    |     3.81s indexing barwar, The Lion With a Swollen Leg...
#    |     3.87s indexing barwar, The Man Who Cried Wolf...
#    |     3.90s indexing barwar, The Man Who Wanted to Work...
#    |     4.11s indexing barwar, The Monk Who Wanted to Know When He Would Die...
#    |     4.16s indexing barwar, The Monk and the Angel...
#    |     4.27s indexing barwar, The Priest and the Mullah...
#    |     4.33s indexing barwar, The Sale of an Ox...
#    |     5.00s indexing barwar, The Scorpion and the Snake...
#    |     5.03s indexing barwar, The Selfish Neighbour...
#    |     5.06s indexing barwar, The Sisisambər Plant...
#    |      |     3.36s 	force-closing sentence in §2.109
#    |      |     3.36s 	force-closing subsentence in §2.109
#    |      |     3.37s 	force-closing sentence in §3.17
#    |      |     3.37s 	force-closing subsentence in §3.17
#    |      |     3.39s 	force-closing sentence in §4.162
#    |      |     3.39s 	force-closing subsentence in §4.162
#    |      |     3.39s 	force-closing sentence in §5.13
#    |      |     3.40s 	force-closing subsentence in §5.13
#    |     5.12s indexing barwar, The Story With No End...
#    |     5.15s indexing barwar, The Tale of Farxo and Səttiya...
#    |     5.56s indexing barwar, The Tale of Mămo and Zine...
#    |     5.96s indexing barwar, The Tale of Mərza Pămət...
#    |     6.15s indexing barwar, The Tale of Nasimo...
#    |      |     4.44s 	force-closing sentence in §0.87
#    |      |     4.45s 	force-closing sentence in §1.38
#    |      |     4.45s 	force-closing subsentence in §1.38
#    |      |     4.46s 	force-closing sentence in §2.21
#    |     6.24s indexing barwar, The Tale of Parizada, Warda and Nargis...
#    |     6.56s indexing barwar, The Tale of Rustam (1)...
#    |     6.71s indexing barwar, The Tale of Rustam (2)...
#    |     6.96s indexing barwar, The Wise Daughter of the King...
#    |     7.03s indexing barwar, The Wise Snake...
#    |      |     5.31s 	force-closing sentence in §0.15
#    |     7.15s indexing barwar, The Wise Young Man...
#    |     7.32s indexing barwar, Šošət Xere...
#    |      |     5.63s 	force-closing sentence in §0.204
#    |      |     5.63s 	force-closing subsentence in §0.204
#    |      |     5.65s 	force-closing sentence in §2.42
#    |     7.39s indexing urmi_c, A Close Shave...
#    |     7.41s indexing urmi_c, A Cure for a Husband’s Madness...
#    |     7.60s indexing urmi_c, A Donkey Knows Best...
#    |     7.62s indexing urmi_c, A Dragon in the Well...
#    |     7.71s indexing urmi_c, A Dutiful Son...
#    |     7.87s indexing urmi_c, A Frog Wants a Husband...
#    |     7.93s indexing urmi_c, A Lost Donkey...
#    |     7.95s indexing urmi_c, A Lost Ring...
#    |     7.96s indexing urmi_c, A Painting of the King of Iran...
#    |     8.09s indexing urmi_c, A Pound of Flesh...
#    |     8.20s indexing urmi_c, A Sweater to Pay Off a Debt...
#    |     8.22s indexing urmi_c, A Thousand Dinars...
#    |      |     6.54s 	foreign letter ŏ̀ encountered...
#    |     8.30s indexing urmi_c, A Visit From Harun Ar-Rashid...
#    |     8.38s indexing urmi_c, Agriculture and Village Life...
#    |     8.77s indexing urmi_c, Am I Dead?...
#    |     8.78s indexing urmi_c, An Orphan Duckling...
#    |     8.80s indexing urmi_c, Axiqar...
#    |     9.24s indexing urmi_c, Events in 1946 on the Urmi Plain...
#    |     9.33s indexing urmi_c, Games...
#    |     9.45s indexing urmi_c, Hunting...
#    |     9.61s indexing urmi_c, I Have Died...
#    |     9.62s indexing urmi_c, Ice for Dinner...
#    |     9.65s indexing urmi_c, Is There a Man With No Worries?...
#    |     9.78s indexing urmi_c, Kindness to a Donkey...
#    |     9.79s indexing urmi_c, Lost Money...
#    |     9.80s indexing urmi_c, Mistaken Identity...
#    |     9.82s indexing urmi_c, Much Ado About Nothing...
#    |      |     8.13s 	foreign letter ä encountered...
#    |      |     8.13s 	foreign letter ä̀ encountered...
#    |      |     8.14s 	foreign letter ä encountered...
#    |      |     8.14s 	foreign letter ä̀ encountered...
#    |     9.91s indexing urmi_c, Nipuxta...
#    |     9.97s indexing urmi_c, No Bread Today...
#    |       10s indexing urmi_c, Problems Lighting a Fire...
#    |       10s indexing urmi_c, St. Zayya’s Cake Dough...
#    |       10s indexing urmi_c, Star-Crossed Lovers...
#    |       10s indexing urmi_c, Stomach Trouble...
#    |       10s indexing urmi_c, The Adventures of Ashur...
#    |      |     8.51s 	foreign letter ǜ encountered...
#    |       11s indexing urmi_c, The Adventures of Two Brothers...
#    |       11s indexing urmi_c, The Adventures of a Princess...
#    |      |     9.45s 	foreign letter ǘ encountered...
#    |      |     9.46s 	foreign letter ǘ encountered...
#    |      |     9.46s 	foreign letter ü encountered...
#    |      |     9.46s 	foreign letter ü encountered...
#    |      |     9.49s 	foreign letter ǘ encountered...
#    |      |     9.49s 	foreign letter ǘ encountered...
#    |      |     9.50s 	foreign letter ü encountered...
#    |       11s indexing urmi_c, The Angel of Death...
#    |       11s indexing urmi_c, The Assyrians of Armenia...
#    |       11s indexing urmi_c, The Assyrians of Urmi...
#    |       12s indexing urmi_c, The Bald Child and the Monsters...
#    |       12s indexing urmi_c, The Bald Man and the King...
#    |       12s indexing urmi_c, The Bird and the Fox...
#    |       12s indexing urmi_c, The Cat’s Dinner...
#    |       12s indexing urmi_c, The Cow and the Poor Girl...
#    |       13s indexing urmi_c, The Dead Rise and Return...
#    |       13s indexing urmi_c, The Fisherman and the Princess...
#    |       13s indexing urmi_c, The Giant One-Eyed Demon...
#    |       13s indexing urmi_c, The Little Prince and the Snake...
#    |       13s indexing urmi_c, The Loan of a Cooking Pot...
#    |       13s indexing urmi_c, The Man Who Wanted to Complain to God...
#    |       13s indexing urmi_c, The Old Man and the Fish...
#    |       13s indexing urmi_c, The Purchase of a Donkey...
#    |       13s indexing urmi_c, The Snake’s Dilemma...
#    |       14s indexing urmi_c, The Stupid Carpenter...
#    |      |       12s 	foreign letter ã̀ encountered...
#    |       14s indexing urmi_c, The Wife Who Learns How to Work (2)...
#    |       14s indexing urmi_c, The Wife Who Learns How to Work...
#    |       14s indexing urmi_c, The Wife’s Condition...
#    |       14s indexing urmi_c, The Wise Brother...
#    |       15s indexing urmi_c, The Wise Young Daughter...
#    |       15s indexing urmi_c, Trickster...
#    |       15s indexing urmi_c, Two Birds Fall in Love...
#    |       15s indexing urmi_c, Two Wicked Daughters-In-Law...
#    |      |       13s 	foreign letter ü encountered...
#    |      |       13s 	foreign letter ü encountered...
#    |       15s indexing urmi_c, Village Life (2)...
#    |       15s indexing urmi_c, Village Life (3)...
#    |      |       13s 	foreign letter ý encountered...
#    |       15s indexing urmi_c, Village Life (4)...
#    |       16s indexing urmi_c, Village Life (5)...
#    |       16s indexing urmi_c, Village Life (6)...
#    |       16s indexing urmi_c, Village Life...
#    |       16s indexing urmi_c, Vineyards...
#    |       16s indexing urmi_c, Weddings and Festivals...
#    |       16s indexing urmi_c, Weddings...
#    |       17s indexing urmi_c, When Shall I Die?...
#    |      |       15s 	foreign letter ŏ́ encountered...
#    |       17s indexing urmi_c, Women Are Stronger Than Men...
#    |       17s indexing urmi_c, Women Do Things Best...
#    |       17s "edge" actions: 0
#    |       17s "feature" actions: 4304221
#    |       17s "node" actions: 295347
#    |       17s "resume" actions: 0
#    |       17s "slot" actions: 541384
#    |       17s "terminate" actions: 836857
#    |          3 x "dialect" node
#    |      36594 x "inton" node
#    |     541384 x "letter" node  = slot type
#    |       2587 x "line" node
#    |        351 x "paragraph" node
#    |      16369 x "sentence" node
#    |      94101 x "stress" node
#    |      24617 x "subsentence" node
#    |        127 x "text" node
#    |     120598 x "word" node
#    |     836731 nodes of all types
#    |       17s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking features ...
#    |     0.00s OK
#    |     0.00s reordering nodes ...
#    |     0.17s Sorting 3 nodes of type "dialect"
#    |     0.21s Sorting 36594 nodes of type "inton"
#    |     0.33s Sorting 2587 nodes of type "line"
#    |     0.37s Sorting 351 nodes of type "paragraph"
#    |     0.42s Sorting 16369 nodes of type "sentence"
#    |     0.51s Sorting 94101 nodes of type "stress"
#    |     0.72s Sorting 24617 nodes of type "subsentence"
#    |     0.85s Sorting 127 nodes of type "text"
#    |     0.89s Sorting 120598 nodes of type "word"
#    |     1.11s Max node = 836731
#    |     1.11s OK
#    |     0.00s reassigning feature values ...
#    |      |       17s node feature "dialect" with 130 nodes
#    |      |       17s node feature "full" with 661982 nodes
#    |      |       17s node feature "full_end" with 120586 nodes
#    |      |       17s node feature "fuzzy" with 661982 nodes
#    |      |       17s node feature "fuzzy_end" with 120598 nodes
#    |      |       17s node feature "lang" with 120598 nodes
#    |      |       17s node feature "line_number" with 2587 nodes
#    |      |       17s node feature "lite" with 661982 nodes
#    |      |       17s node feature "lite_end" with 120586 nodes
#    |      |       17s node feature "phonation" with 307888 nodes
#    |      |       18s node feature "phonetic_class" with 541366 nodes
#    |      |       18s node feature "phonetic_manner" with 312113 nodes
#    |      |       18s node feature "phonetic_place" with 312113 nodes
#    |      |       18s node feature "place" with 127 nodes
#    |      |       18s node feature "speaker" with 120598 nodes
#    |      |       18s node feature "speakers" with 126 nodes
#    |      |       18s node feature "text" with 661982 nodes
#    |      |       18s node feature "text_end" with 120598 nodes
#    |      |       18s node feature "text_id" with 126 nodes
#    |      |       18s node feature "text_nostress" with 661982 nodes
#    |      |       18s node feature "text_nostress_end" with 120586 nodes
#    |      |       18s node feature "timestamp" with 447 nodes
#    |      |       18s node feature "title" with 127 nodes
#    |     1.91s OK
#   0.00s Exporting 24 node and 1 edge and 1 config features to tf:
#   0.00s VALIDATING oslots feature
#   0.11s VALIDATING oslots feature
#   0.11s maxSlot=     541384
#   0.11s maxNode=     836731
#   0.18s OK: oslots is valid
#    |     0.00s T dialect              to tf
#    |     0.75s T full                 to tf
#    |     0.13s T full_end             to tf
#    |     0.67s T fuzzy                to tf
#    |     0.13s T fuzzy_end            to tf
#    |     0.12s T lang                 to tf
#    |     0.00s T line_number          to tf
#    |     0.72s T lite                 to tf
#    |     0.13s T lite_end             to tf
#    |     0.21s T otype                to tf
#    |     0.34s T phonation            to tf
#    |     0.57s T phonetic_class       to tf
#    |     0.34s T phonetic_manner      to tf
#    |     0.34s T phonetic_place       to tf
#    |     0.00s T place                to tf
#    |     0.14s T speaker              to tf
#    |     0.00s T speakers             to tf
#    |     0.76s T text                 to tf
#    |     0.17s T text_end             to tf
#    |     0.00s T text_id              to tf
#    |     0.76s T text_nostress        to tf
#    |     0.19s T text_nostress_end    to tf
#    |     0.00s T timestamp            to tf
#    |     0.00s T title                to tf
#    |     1.30s T oslots               to tf
#    |     0.00s M otext                to tf
#   7.98s Exported 24 node features and 1 edge features and 1 config features to tf

# %%
cp.errors
# Out:
# {'nena_parser': [], 'tf_builder': []}

# %%
from tf.client.make.build import makeSearchClients
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7c09f7dc13c6> in <module>
# ----> 1 from tf.client.make.build import makeSearchClients
#
# ModuleNotFoundError: No module named 'tf.client.make'
