# %% [markdown]
# # Convert Barwar Glossary for Verbs into Inflections and Lexicon

# %%
import re
import collections
from bs4 import BeautifulSoup
import mammoth
import unicodedata as ud
from pprint import pprint

with open('bar glossary verbs_modded.docx', 'rb') as docx_file:
    result = mammoth.convert_to_html(docx_file)
    html = result.value # The generated HTML
    messages = result.messages # Any messages, such as warnings during conversion
    
soup = BeautifulSoup(html, 'html.parser') # parse HTML
elements = list(soup) # grab elements
entries = [
    e for e in elements[40:]
        if len(list(e.children)) > 3
]

len(entries)
# Out:
# 977

# %%
entries_parsed = collections.defaultdict(dict)
stem_marker = re.compile(r'(^|\s)(I+|Q)($|\s)')
stem_marker_end = re.compile(r'(I+|Q)$')
stem_marker_plain = re.compile(r'(I+|Q)')
defi_number = re.compile(r'\(\d+\)')
ref_tag = re.compile(r'\(.+:.+\)')
sent_end = re.compile(r'(?<!\.)\.(?!\.)|;|[!?]+|:')
lex_number = re.compile(r'\([iv]+\)')
lang_tag = re.compile(r'\([A-Z]+\.?\)')
stress_accents = re.compile(r'\u0300|\u0301')

def get_string(element, strip=True, normalize=True):
    """Retrieve a string regardless of element's class type"""
    string = getattr(element, 'text', str(element))
    string = string.strip() if strip else string
    string = ud.normalize('NFD', string) if normalize else string
    return string

def match_inflection(element, debug=False):
    """Identify inflection markers"""
    prev_sib = element.previous_sibling
    next_sib = element.next_sibling

    rules = [
        element.name == 'em',
        get_string(prev_sib).endswith('('),
        get_string(next_sib).startswith(')'),
    ]
    if debug: 
        print(rules)
    return all(rules)

def match_inton_end(element):
    """Match ending | intonation marker"""
    rules = [
        getattr(element,'name','') == 'sup',
        '|' in get_string(element),
    ]
    return all(rules)

def match_sentence(element, debug=False):
    """Match instances of example texts"""
    text = get_string(element)
    next_sib = element.next_sibling
    any_rules = [
        sent_end.search(text),
        stress_accents.search(text),
        '|' in text,
        match_inton_end(next_sib),
        ref_tag.search(text),
    ]
    rules = [
        bool(text),
        any(any_rules),
    ]
    if debug:
        print('any', any_rules)
        print('all', rules)
    return all(rules)

def match_wordform(element, debug=False):
    """Match a wordform of a lexeme."""
    text = get_string(element)
    prev_sib = element.previous_sibling
    next_sib = element.next_sibling 
    rules = [
        bool(text),
        getattr(element,'name','') == 'em',
        not match_inflection(element),
        not match_sentence(element),
        '→' not in text,
        not get_string(prev_sib).endswith('→'),
        not get_string(next_sib).startswith('-'),
    ]
    if next_sib:
        rules.append(not match_sentence(next_sib))
    if debug:
        print(rules)
    return all(rules)
    
def match_stem(element, debug=False):
    """Match a stem marker"""
    text = get_string(element)
    rules = [
        stem_marker.match(text) or stem_marker_end.search(text),
        not sent_end.search(text),
    ]
    if debug:
        print(rules)
    return all(rules)
    
def match_gloss(element):
    """Identify element containing gloss."""
    prev_sib = element.previous_sibling
    psib_text = get_string(prev_sib)
    rules = [
        getattr(element,'name','') == 'strong',
        getattr(element,'text','').strip().startswith('to'),
        not defi_number.search(psib_text),
    ]
    return all(rules)
    
def match_lex_number(element, debug=False):
    """Identify a lexeme number"""
    text = get_string(element)
    return bool(lex_number.match(text))

def match_lang_tag(element, debug=False):
    text = get_string(element)
    return bool(lang_tag.search(text))
    
def findall_types(element):
    """Run all match tests as parsings."""
    match_set = [
        ('cons', match_wordform),
        ('stem', match_stem),
        ('lex_number', match_lex_number),
        ('inflections', match_inflection), 
        ('language', match_lang_tag),
        ('gloss', match_gloss),
    ]
    matches = []
    for child in element.children:
        for tag, matcher in match_set:
            if matcher(child):
                matches.append((tag, get_string(child, normalize=False)))
    return matches

# %%
# test mass parsings

parses = []
for entry in entries:
    parsed_entry = findall_types(entry)
    parses.append((parsed_entry, entry))

# %%
# cluster into forms

root2stems = {}

def cluster_stems(parsing):
    """Cluster data by stem and map to root string.
    
    Data is parsed as a list of elements. The elements
    here are split up by stem and delivered as a dictionary
    with a root:stem_lists mapping, where root is the first
    word form in the entry and stem_lists is a list where
    each correspons with a list of metadata.
    """
    
    # cluster by appending to embedded list
    # when encountering a stem tag that is not 
    # first, add a new list for clustering
    data = [[]]
    first_stem = False
    root = parsing[0][1]
    
    for tag, text in parsing[1:]:
        
        if tag == 'stem':
            text = stem_marker_plain.findall(text)[0] # clean up the stem tag
            if not first_stem:
                first_stem = True
            else:
                data.append([]) # put new data group
                
        elif tag == 'lex_number':
            root += ' ' + text
            continue
                
        data[-1].append((tag, text))

    return {root: data}

for parsing, entry in parses:
    root2stems.update(cluster_stems(parsing))

# %%
for root in list(root2stems.keys())[:100]:
    print(root)
    pprint(root2stems[root])
    print()
# Out:
# ʾby
# [[('stem', 'III'),
#   ('cons', 'm-by'),
#   ('inflections', 'mabe/măbe, mubele/mŭbele, maboye/măboye'),
#   ('gloss', 'to swell; to cause to swell, to inflate')]]
#
# ʾč̣m
# [[('stem', 'I'),
#   ('inflections', 'ʾač̣əm, č̣imle, č̣ama'),
#   ('gloss', 'to close')]]
#
# ʾjb
# [[('stem', 'III'),
#   ('cons', 'm-jb'),
#   ('inflections', 'majəb/măjəb, mŭjəble/ʾŭjəble, măjobe'),
#   ('gloss', 'to be astonished, to be amazed')]]
#
# ʾmð
# [[('stem', 'I'),
#   ('inflections', 'ʾaməð, midle, maða'),
#   ('gloss', 'to be baptized')],
#  [('stem', 'III'),
#   ('cons', 'm-mð'),
#   ('inflections', 'maməð/măməð, mŭməðme, mămoðe'),
#   ('gloss', 'to baptize')]]
#
# ʾmr
# [[('stem', 'I'), ('inflections', 'ʾamər, məre, mara'), ('gloss', 'to say')]]
#
# ʾmṣ
# [[('stem', 'I'), ('inflections', 'y-aməṣ'), ('gloss', 'to be able')]]
#
# ʾqð
# [[('stem', 'I'),
#   ('inflections', 'ʾaqəð, qidle, qaða'),
#   ('gloss', 'to burn (intr.)')],
#  [('stem', 'III'),
#   ('cons', 'm-qð'),
#   ('inflections', 'maqəð, muqəðle, maqoðe'),
#   ('gloss', 'to burn (tr.)')]]
#
# ʾqr
# [[('stem', 'I'),
#   ('inflections', 'ʾaqər, qirre, qara'),
#   ('gloss', 'to dig up, to dig out; to plough; to cost, to be expensive')]]
#
# ʾrml
# [[('stem', 'Q'),
#   ('cons', 'm-rml'),
#   ('inflections', 'marməl, murməlle, marmole'),
#   ('gloss', 'to become a widow/widower')]]
#
# ʾrq
# [[('stem', 'I'),
#   ('inflections', 'ʾarəq, riqle, raqa'),
#   ('gloss', 'to run; to flee; to lose a game.')],
#  [('stem', 'III'),
#   ('cons', 'm-rq'),
#   ('inflections', 'mărəq, mŭrəqle, măroqe'),
#   ('gloss', 'to kidnap; to cause to lose a game.')]]
#
# ʾrql
# [[('stem', 'Q'),
#   ('cons', 'm-rql'),
#   ('inflections', 'marqəl, murqəlle, marqole'),
#   ('gloss', 'to be late')]]
#
# ʾršn
# [[('stem', 'Q'),
#   ('cons', 'm-ršn'),
#   ('inflections', 'maršən, muršənne, maršone'),
#   ('gloss', 'to become mirky; to make mirky (water); to become numb.')]]
#
# ʾrṭ
# [[('stem', 'I'), ('inflections', 'ṭur'), ('gloss', 'to break wind noisily')],
#  [('stem', 'III'),
#   ('cons', 'm‑rṭ'),
#   ('inflections', 'mărəṭ, mŭrəṭle, măroṭe'),
#   ('gloss', 'to break wind noisily')]]
#
# ʾry (i)
# [[('stem', 'I'), ('inflections', 'ʾare, rele, raya'), ('gloss', 'to rain')]]
#
# ʾry (ii)
# [[('stem', 'I'),
#   ('inflections', 'ʾare, rele, raya'),
#   ('gloss', 'to seize; to curdle.')],
#  [('stem', 'III'),
#   ('cons', 'm-ry'),
#   ('inflections', 'mare, murele, maroye'),
#   ('gloss', 'to patch; to cause to curdle.')]]
#
# ʾšq
# [[('stem', 'I'),
#   ('inflections', 'ʾašəq, šiqle, šaqa'),
#   ('language', ') (A.)'),
#   ('gloss', 'to be in love')]]
#
# ʾsq
# [[('stem', 'I'),
#   ('inflections', 'ʾasəq, siqle, saqa'),
#   ('gloss',
#    'to go up; to go towards; to go off; to be descended (by genealogy).')],
#  [('stem', 'III'),
#   ('cons', 'm-sq'),
#   ('inflections', 'masəq, musəqle, masoqe'),
#   ('gloss', 'to take up; to bring towards; to load (a gun).')]]
#
# ʾsṛ
# [[('stem', 'I'), ('inflections', 'ʾasəṛ, siṛṛe, saṛa'), ('gloss', 'to tie')]]
#
# ʾṣy
# [[('stem', 'I'),
#   ('inflections', 'ʾaṣe, ṣele, ṣaya'),
#   ('gloss', 'to resist, to get stuck')],
#  [('stem', 'III'),
#   ('cons', 'm‑ṣy'),
#   ('inflections', 'maṣe/măṣe, muṣele/mŭṣele, maṣoye/măṣoye'),
#   ('gloss', 'to fortify')]]
#
# ʾtw
# [[('stem', 'I'),
#   ('inflections', 'ʾatu, tiwle, tawa'),
#   ('gloss', 'to sit; to dwell; to be situated; to settle; to drop.')],
#  [('stem', 'III'),
#   ('cons', 'm-ty'),
#   ('inflections', 'mattu, muttule, mattoye'),
#   ('gloss',
#    'to place; to lay down, to shed; to set up; to lay out; to put aside.')]]
#
# ʾθy
# [[('stem', 'I'),
#   ('inflections', 'ʾaθe, θele, θaya'),
#   ('gloss',
#    'to come; to come back; to come to (do sth. eventually); to happen; to be '
#    'told.')],
#  [('stem', 'III'),
#   ('cons', 'm-θy'),
#   ('inflections', 'mɛθe/mɛye, muθele, mɛθoye'),
#   ('gloss', 'to bring; to bring back; to collect (taxes); to give birth to.')]]
#
# ʾwð
# [[('stem', 'I'),
#   ('inflections', 'ʾawəð, widle, waða'),
#   ('gloss',
#    'to do, to make; to treat (wound); to move, to put; to pick, to collect'),
#   ('cons', 'ta-/ṭla-')]]
#
# ʾwr
# [[('stem', 'I'),
#   ('inflections', 'ʾawər, wirre, wara'),
#   ('gloss', 'to pass; to enter.')],
#  [('stem', 'III'),
#   ('cons', 'm-wr'),
#   ('inflections', 'mawər, muwərre, mawore'),
#   ('gloss', 'to bring in; to pass (time).')]]
#
# ʾxl
# [[('stem', 'I'), ('inflections', 'ʾaxəl, xille, xala'), ('gloss', 'to eat')],
#  [('stem', 'III'),
#   ('cons', 'm-xl'),
#   ('inflections', 'maxəl, muxəlle, maxole'),
#   ('gloss', 'to let eat, to feed')]]
#
# ʾyd
# [[('stem', 'I'), ('inflections', 'ʾayəd, yidle, yada'), ('gloss', 'to weed')]]
#
# ʾyq
# [[('stem', 'I'),
#   ('inflections', 'ʾayəq, yiqle, yaqa'),
#   ('gloss', 'to become narrow, to become tight; to become distressed.')]]
#
# ʾzl (i)
# [[('stem', 'I'),
#   ('inflections', 'ʾazəl, zille, zala'),
#   ('gloss',
#    'to go; to go along, to flow; to go by (time); to go for (be sold); to '
#    'perish.')]]
#
# ʾzl (ii)
# [[('stem', 'I'),
#   ('inflections', 'ʾazəl, zille, zala'),
#   ('gloss', 'to spin (wool)')]]
#
# ʿjz
# [[('stem', 'II'),
#   ('inflections', 'mʿajəz, mʿujəzle, mʿajoze'),
#   ('gloss', 'to become senile')]]
#
# ʿqm
# [[('stem', 'II'),
#   ('cons', 'm-ʿqm'),
#   ('inflections', 'mʿăqəm, mʿŭqəmle, mʿăqome'),
#   ('gloss', 'to sterilize')]]
#
# ʿyn
# [[('stem', 'II'),
#   ('cons', 'm-ʿyn'),
#   ('inflections', 'mʿayən, mʿuyənne, mʿayone'),
#   ('language', ') (A.)'),
#   ('gloss', 'to help')]]
#
# bdd
# [[('stem', 'II'),
#   ('cons', 'm-bdd'),
#   ('inflections', 'mbădəd, mbŭdədle, mbădode'),
#   ('gloss', 'to stir a fire with a poker')]]
#
# bdl
# [[('stem', 'I'),
#   ('inflections', 'badəl, bdille, bdala'),
#   ('gloss', 'to fade; to change (colour)')]]
#
# bdy
# [[('stem', 'I'),
#   ('inflections', 'bade, bdele, bdaya'),
#   ('language', ') (A.)'),
#   ('gloss', 'to begin')]]
#
# bðq
# [[('stem', 'I'),
#   ('inflections', 'baðəq, bðiqle, bðaqa'),
#   ('gloss', 'to scatter (seed)')]]
#
# bðr
# [[('stem', 'I'),
#   ('inflections', 'baðər, bðirre, bðara'),
#   ('gloss', 'to scatter; to spill')],
#  [('stem', 'II'),
#   ('cons', 'm-bðr'),
#   ('inflections', 'mbaðər, mbuðərre, mbaðore'),
#   ('gloss', 'to scatter; to spill')]]
#
# bhrn
# [[('stem', 'Q'),
#   ('cons', 'm-bhrn'),
#   ('inflections', 'mbahrən, mbuhrənle, mbahrone'),
#   ('gloss', 'to shine')]]
#
# bjbj
# [[('stem', 'Q'),
#   ('cons', 'm-bjbj'),
#   ('inflections', 'mbajbəj, mbujbəjle, mbajboje'),
#   ('gloss', 'to move, to budge')]]
#
# blʾ
# [[('stem', 'I'),
#   ('inflections', 'băle, blile/blele, blaʾa/blaya'),
#   ('gloss', 'to swallow')]]
#
# blbl
# [[('stem', 'Q'),
#   ('cons', 'm-blbl'),
#   ('inflections', 'mbalbəl, mbulbəlle, mbalbole'),
#   ('gloss', 'to ruffle, to dishevel')]]
#
# blby
# [[('stem', 'Q'),
#   ('cons', 'm-blby'),
#   ('inflections', 'mbalbe, mbulbele, mbalboye'),
#   ('gloss', 'to search (inside a container)')]]
#
# blq
# [[('stem', 'II'),
#   ('cons', 'm-blq'),
#   ('inflections', 'mbaləq, mbuləqle, mbaloqe'),
#   ('gloss', 'to stare; to fix (eyes)')]]
#
# bls
# [[('stem', 'I'),
#   ('inflections', 'baləs, blisle, blasa'),
#   ('gloss', 'to damage; to make jagged')],
#  [('stem', 'II'),
#   ('cons', 'm-bls'),
#   ('inflections', 'mbăləs, mbăləsa, mbŭləsle, mbălose'),
#   ('gloss', 'to tear apart with teeth or hands (food)')]]
#
# bly
# [[('stem', 'I'),
#   ('inflections', 'bale, blele, blaya'),
#   ('gloss', 'to wear out')]]
#
# bny
# [[('stem', 'I'),
#   ('inflections', 'bane, bnele, bnaya'),
#   ('gloss', 'to build; to stack up')],
#  [('stem', 'II'),
#   ('cons', 'm-bny'),
#   ('inflections', 'mbane, mbunele, mbanoye'),
#   ('gloss', 'to prepare food for serving (without cooking)')],
#  [('stem', 'III'),
#   ('cons', 'm-bny'),
#   ('inflections', 'mabne, mubnele, mabnoye'),
#   ('gloss', 'to cause to build, to cause to be built')]]
#
# bqbq
# [[('stem', 'Q'),
#   ('cons', 'm-bqbq'),
#   ('inflections', 'mbaqbəq, mbuqbəqle, mbaqboqe'),
#   ('gloss', 'to gurgle (water)')]]
#
# bqr
# [[('stem', 'II'),
#   ('cons', 'm-bqr'),
#   ('inflections', 'mbaqər, mbuqərle, mbaqore'),
#   ('gloss', 'to ask')]]
#
# brbq
# [[('stem', 'Q'),
#   ('cons', 'm-brbq'),
#   ('inflections', 'mbarbəq, mburbəqle, mbarboqe'),
#   ('gloss', 'to shake')]]
#
# brbr
# [[('stem', 'Q'),
#   ('cons', 'm-brbr'),
#   ('inflections', 'mbarbər, mburbərre, mbarbore'),
#   ('gloss', 'to bleat (sheep); to low (cattle)')]]
#
# brbṭ
# [[('stem', 'Q'),
#   ('cons', 'm-brbṭ'),
#   ('inflections', 'mbarbəṭ, mburbəṭle, mbarboṭe'),
#   ('gloss', 'to shudder')]]
#
# brbz
# [[('stem', 'Q'),
#   ('cons', 'm-brbz'),
#   ('inflections', 'mbarbəz, mburbəzle, mbarboze'),
#   ('gloss', 'to scatter; to be scattered')]]
#
# brd
# [[('stem', 'I'),
#   ('inflections', 'barəd, bridle, brada'),
#   ('gloss', 'to rub; to scour')]]
#
# brdm
# [[('stem', 'Q'),
#   ('cons', 'm-brdm'),
#   ('inflections', 'mbardəm, mburdəmle, mbardome'),
#   ('gloss', 'to mumble, to mutter')]]
#
# brk
# [[('stem', 'I'),
#   ('inflections', 'barək, brikle, braka'),
#   ('gloss', 'to kneel')]]
#
# brq
# [[('stem', 'I'),
#   ('inflections', 'barəq, briqle, braqa'),
#   ('gloss', 'to shine')],
#  [('stem', 'III'),
#   ('cons', 'm-brq'),
#   ('inflections', 'mabrəq, mubrəqle, mabroqe'),
#   ('gloss', 'to cause to shine')]]
#
# brṭ
# [[('stem', 'II'),
#   ('cons', 'm-brṭ'),
#   ('inflections', 'mbarəṭ, mburəṭle, mbaroṭe'),
#   ('gloss', 'to roll over (in sleep)')]]
#
# brtl
# [[('stem', 'Q'),
#   ('cons', 'm-brtl'),
#   ('inflections', 'mbartəl, mburtəlle, mbartote'),
#   ('gloss', 'to bribe')]]
#
# brx
# [[('stem', 'II'),
#   ('cons', 'm-brx'),
#   ('inflections', 'mbarəx, mburəxle, mbaroxe'),
#   ('gloss', 'to bless; to sanctify a marriage, to marry; to greet.')]]
#
# brxš
# [[('stem', 'Q'),
#   ('cons', 'm-brxš'),
#   ('inflections', 'mbarxəš, mburxəšle, mbarxoše'),
#   ('gloss', 'to mix; to stir')]]
#
# bry
# [[('stem', 'I'),
#   ('inflections', 'bare, brele, braya'),
#   ('gloss',
#    'to be born; to grow; to separate from; to happen; to be possible.')],
#  [('stem', 'III'),
#   ('cons', 'm-bry'),
#   ('inflections', 'mabre, mubrele, mabroye'),
#   ('gloss', 'to give birth')]]
#
# brz
# [[('stem', 'I'),
#   ('inflections', 'barəz, brizle, braza'),
#   ('gloss', 'to become dry')],
#  [('stem', 'II'),
#   ('cons', 'm-brz'),
#   ('inflections', 'mbarəz, mburəzle, mbaroze'),
#   ('gloss', 'to dry (tr.); to drain')],
#  [('stem', 'III'),
#   ('cons', 'm-brz'),
#   ('inflections', 'mabrəz, mubrəzle, mabroze'),
#   ('gloss', 'to dry (tr.)')]]
#
# bsm
# [[('stem', 'I'),
#   ('inflections', 'basəm, bsimle, bsama'),
#   ('gloss',
#    'to be pleasant, pleasing; to be healthy, to be cured; to become sharp.')],
#  [('stem', 'II'),
#   ('cons', 'm-bsm'),
#   ('inflections', 'mbasəm, mbusəmle, mbasome'),
#   ('gloss', 'to cure; to make fit, to prepare.')],
#  [('stem', 'III'),
#   ('cons', 'm-bsm'),
#   ('inflections', 'mabsəm, mubsəmle, mabsome'),
#   ('gloss', 'to enjoy o.s.; to cause to enjoy, to entertain')]]
#
# bsty
# [[('stem', 'Q'),
#   ('cons', 'm-bsty'),
#   ('inflections', 'mbaste, mbustele, mbastoye'),
#   ('gloss', 'to become an ally; to feel comfortable, to feel at home')]]
#
# bṣlṣ
# [[('stem', 'Q'),
#   ('cons', 'm-bṣlṣ'),
#   ('inflections', 'mbaṣləṣ, mbuṣləṣle, mbaṣloṣe'),
#   ('gloss', 'to shine, to glow')]]
#
# bṣr
# [[('stem', 'I'),
#   ('inflections', 'baṣər, bṣirre, bṣara'),
#   ('gloss', 'to diminish, to become less, to deteriorate')],
#  [('stem', 'III'),
#   ('cons', 'm-bṣr'),
#   ('inflections', 'mabṣər, mubṣərre, mabṣore'),
#   ('gloss', 'to cause to diminish, to reduce, to subtract')]]
#
# bšl
# [[('stem', 'I'),
#   ('inflections', 'bašəl, bšille, bšala'),
#   ('gloss', 'to cook (intr.)')],
#  [('stem', 'II'),
#   ('cons', 'm-bšl'),
#   ('inflections', 'mbašəl, mbušəlle, mbašole'),
#   ('gloss', 'to cook (tr.)')]]
#
# btt
# [[('stem', 'II'),
#   ('cons', 'm-btt'),
#   ('inflections', 'mbatət/mbătət, mbutətle/mbŭtətle, mbatote/mbătote'),
#   ('gloss', 'to investigate')]]
#
# bṭl
# [[('stem', 'I'),
#   ('inflections', 'baṭəl, bṭille, bṭala'),
#   ('gloss', 'to stop (intr.); to be idle, unproductive')],
#  [('stem', 'II'),
#   ('cons', 'm-bṭl'),
#   ('inflections', 'mbaṭəl, mbuṭəlle, mbaṭole'),
#   ('gloss', 'to cause to stop; to eliminate, to get rid of')]]
#
# bwby
# [[('stem', 'Q'),
#   ('cons', 'm-bwby'),
#   ('inflections', 'mbawbe, mbubele, mbawboye'),
#   ('gloss', 'to howl (wolf)')]]
#
# bxl
# [[('stem', 'II'),
#   ('cons', 'm-bxl'),
#   ('inflections', 'mbaxəl, mbuxəlle, mbaxole'),
#   ('gloss', 'to be jealous, to envy')]]
#
# bxr
# [[('stem', 'I'),
#   ('inflections', 'baxər, bxirre, bxara'),
#   ('gloss', 'to steam')]]
#
# bxy
# [[('stem', 'I'), ('inflections', 'baxe, bxele, bxaya'), ('gloss', 'to weep')]]
#
# by
# [[('stem', 'I'),
#   ('inflections', 'băye, bele, băya'),
#   ('gloss', 'to want, to need; to love, to like.')]]
#
# byč̣
# [[('stem', 'III'),
#   ('cons', 'm-byč̣'),
#   ('inflections', 'mabyəč̣/măbič̣, mubyəč̣le/mŭbič̣le, mabyoč̣e/măboč̣e'),
#   ('gloss', 'to give birth to a bastard')]]
#
# byn
# [[('stem', 'II'),
#   ('cons', 'm-byn'),
#   ('inflections', 'mbayən, mbuyənne, mbayone'),
#   ('gloss', 'to appear')],
#  [('stem', 'III'),
#   ('cons', 'm-byn'),
#   ('inflections', 'mabyən/măbin, mubyənne/mŭbinne, mabyone/măbone'),
#   ('gloss', 'to appear; to cause to appear; to come to visit')]]
#
# byx
# [[('stem', 'I'),
#   ('inflections', 'bayəx, bixle, byaxa'),
#   ('gloss', 'to overflow')]]
#
# byz
# [[('stem', 'I'),
#   ('inflections', 'bayəz, bizle, byaza'),
#   ('gloss', 'to pour, to spill')]]
#
# bzʾ
# [[('stem', 'I'),
#   ('inflections', 'băze, bzile/bzele, bzaʾa/bzaya'),
#   ('gloss', 'to cleave, to make a hole; to be punctured, pierced')]]
#
# bzmr
# [[('stem', 'Q'),
#   ('cons', 'm-bzmr'),
#   ('inflections', 'mbazmər, mbuzmərre, mbazmore'),
#   ('gloss', 'to nail')]]
#
# bzq
# [[('stem', 'I'),
#   ('inflections', 'bazəq, bziqle, bzaqa'),
#   ('gloss', 'to scatter (seed)')]]
#
# čfl
# [[('stem', 'I'),
#   ('inflections', 'čafəl, čfille, čfala'),
#   ('language', ') (A.)'),
#   ('gloss', 'to be startled')]]
#
# čk̭bn
# [[('stem', 'Q'),
#   ('cons', 'm-čk̭bn'),
#   ('inflections', 'mčak̭bən, mčuk̭bənne, mčak̭bone'),
#   ('language', ') (K.)'),
#   ('gloss', 'to arm (with weapons); to deck out')]]
#
# čkčk
# [[('stem', 'Q'),
#   ('cons', 'm-čkčk'),
#   ('inflections', 'mčakčək, mčukčəkle, mčakčoke'),
#   ('gloss', 'to chatter; to clatter; to prick')]]
#
# člms
# [[('stem', 'Q'),
#   ('cons', 'm-člms'),
#   ('inflections', 'mčalməs, mčulməsle, mčalmose'),
#   ('gloss', 'to be sore, to sting (eyes)')]]
#
# člwl
# [[('stem', 'Q'),
#   ('cons', 'm-člwl'),
#   ('inflections', 'mčalwəl, mčulwəlle, mčalwole'),
#   ('gloss', 'to wail')]]
#
# čmbl
# [[('stem', 'Q'),
#   ('cons', 'm-čmbl'),
#   ('inflections', 'mčambəl, mčumbəlle, mčambole'),
#   ('language', ') (K.)'),
#   ('gloss', 'to hook (sth. onto sth.)')]]
#
# čnčl
# [[('stem', 'Q'),
#   ('cons', 'm-čnčl'),
#   ('inflections', 'mčančəl, mčunčəlle, mčančole'),
#   ('gloss', 'to egg on (a straggler)')]]
#
# čngl
# [[('stem', 'Q'),
#   ('cons', 'm-čngl'),
#   ('inflections', 'mčangole, mčungəlle, mčangole'),
#   ('language', ') (K.)'),
#   ('gloss', 'to roll; to roll over;')]]
#
# črčr
# [[('stem', 'Q'),
#   ('cons', 'm-črčr'),
#   ('inflections', 'mčarčər, mčurčərre, mčarčore'),
#   ('gloss', 'to talk garrulously; to screach')]]
#
# črk
# [[('stem', 'II'),
#   ('cons', 'm-črk'),
#   ('inflections', 'mčarək, mčurəkle, mčaroke'),
#   ('gloss', 'to surround')]]
#
# črqy
# [[('stem', 'Q'),
#   ('cons', 'm-črqy'),
#   ('inflections', 'mčarqe, mčurqele, mčarqoye'),
#   ('gloss', 'to fire (gun); to spring (a trap)')]]
#
# črx
# [[('stem', 'I'),
#   ('inflections', 'čarəx, črixle, čraxa'),
#   ('gloss', 'to go around; to take around')]]
#
# čwčy
# [[('stem', 'Q'),
#   ('cons', 'm-čwčy'),
#   ('inflections', 'mčawče, mčučele, mčawčoye'),
#   ('gloss', 'to chirp')]]
#
# čx
# [[('stem', 'III'),
#   ('cons', 'm-čx'),
#   ('inflections', 'mačəx/măčəx, mŭčəxle, măčoxe'),
#   ('gloss', 'to find')]]
#
# čxs
# [[('stem', 'II'),
#   ('cons', 'm-čxs'),
#   ('inflections', 'mčaxəs, mčuxəsle, mčaxose'),
#   ('gloss', 'to insult')]]
#
# čy
# [[('stem', 'I'),
#   ('inflections', 'čăye, čele, čăya'),
#   ('gloss', 'to become tired')]]
#
# čyd
# [[('stem', 'I'),
#   ('inflections', 'čayəd, čidle, čyada'),
#   ('gloss', 'to invite')]]
#
# čyk
# [[('stem', 'I'),
#   ('inflections', 'čayək, čikle, čyaka'),
#   ('gloss', 'to jam; to wedge forcibly (into a tight space);'),
#   ('gloss', 'to pierce')]]
#
# čyl
# [[('stem', 'I'),
#   ('inflections', 'čayəq, čiqle, čyaqa'),
#   ('gloss', 'to sprout. III'),
#   ('cons', 'm‑čyl'),
#   ('inflections', 'mačyəl/măčil, mučyəlle/mŭčille, mačyole/măčole'),
#   ('gloss', 'to sprout, to grow; to cause to sprout')]]
#
# čyr
# [[('stem', 'I'),
#   ('inflections', 'čayər, čirle, čyara'),
#   ('gloss',
#    'to turn away in anger, to be offended, annoyed; to become alienated')]]

# %%
# a loop that can be used for checking for empty fields in each entry

# probs = []

# # check for missing word forms
# for root, stems in root2stems.items():
#     for stem_data in stems:
#         data_dict = dict(stem_data)
#         if not set(data_dict.keys()) & {'gloss'}:
#             probs.append(root)
            
# len(probs)

# %%
# a loop for cataloguing all the unique stem strings identified

# stem2examples = collections.defaultdict(list)

# for root, stems in root2stems.items():
#     for stem_data in stems:
#         for tag, value in stem_data:
#             if tag == 'stem':
#                 stem2examples[value].append(root)
            
# stem2examples.keys()

# %%
# a loop for locating particular entries

# for i,entry in enumerate(entries):
#     childs = list(entry.children)
#     if 'hyr' in childs[0].text:
#         print(i, entry)

# %%
# These are rules that I ended up not using
# since we leave the text examples alone for now
# i.e. only interested in a select group of features

# def match_lexeme(element, debug=False):
#     """Identify element containing lexeme."""
    
#     # prepare siblings for rule processing
#     prev_sib = element.previous_sibling
#     psib_txt = get_string(prev_sib)
#     next_sib = element.next_sibling
#     nsib_txt = get_string(next_sib)
#     psib_is_stem = getattr(prev_sib,'name','') != 'em' and stem_marker_end.search(psib_txt)
#     nsib_is_stem = getattr(next_sib,'name','') != 'em' and stem_marker.match(nsib_txt)
#     nsib_is_num = lex_number.match(nsib_txt)
#     text = get_string(element)

#     # test rules
#     rules = [
#         bool(text),
#         element.name == 'em',
#         (psib_is_stem or nsib_is_stem or nsib_is_num),
        
#     ]
#     if debug: 
#         print(rules)
#     return all(rules)

# def match_definition_number(element):
#     """Identify definition numbers"""
#     text = getattr(element,'text','').strip()
#     if defi_number.fullmatch(text):
#         return True

# def match_example(element, debug=False):
#     """Identify element containing NENA example."""
#     next_sib = element.next_sibling
#     nsib_text = get_string(next_sib).strip()
#     text = get_string(element)
#     rules = [
#         getattr(element,'name','') == 'em',
#         getattr(next_sib,'name','') == 'sup',
#         nsib_text == '|',
#     ]
#     if debug: 
#         print(rules)
#     return all(rules)
    
# def match_translation(element, debug=False):
#     """Identify element containing translation of NENA example."""
#     prev_sib = element.previous_sibling
#     psib_text = get_string(prev_sib)
#     rules = [
#         getattr(element,'name',None) == None,
#         getattr(prev_sib,'name','') == 'sup',
#         psib_text == '|',
#     ]
#     if debug: 
#         print(rules)
#     return all(rules)

# -- test cases --

# gxk_case = entries[200]
# hwy_case = entries[213]
# hyr_case = entries[215]
# hyr2_case = entries[216]
# hymn_case = entries[214]
# gyd_case = entries[201]

# for i,entry in enumerate(entries):
#     childs = list(entry.children)
#     if 'gyð ' in childs[0].text:
#         print(i, entry)
